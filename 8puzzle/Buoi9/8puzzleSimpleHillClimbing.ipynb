# %%
import copy

winMatrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 0],
]

data = list(map(int, input("Nhập ma trận: ").split()))
matrix = [data[i:i+3] for i in range(0, 9, 3)]

father = None
action = None
step = 0

def costCal(thisMatrix):
    hn = 0
    x1 = x2 = y1 = y2 = 0
    for a in range(1,9):
        for i in range(3):
            for j in range(3):
                if thisMatrix[i][j] == a:
                    x1, y1 = i, j
        for i in range(3):
            for j in range(3):
                if winMatrix[i][j] == a:
                    x2, y2 = i, j
        hn = hn + abs(x1 - x2) + abs(y1 - y2)
    return hn

cost = costCal(matrix)

info = [[matrix, father, action, step, cost]]

done = False
while(not done):
    
    for i in range(3):
        for j in range(3):
            if matrix[i][j] == 0:
                x, y = i, j

    moved = False

    if x > 0:
        newMatrix = copy.deepcopy(matrix)
        newMatrix[x][y] = newMatrix[x-1][y]
        newMatrix[x-1][y] = 0
        childCost = costCal(newMatrix)
        if childCost < cost:
            matrix = newMatrix
            cost = childCost
            step = step+1
            info.append([newMatrix, matrix, "UP", step, cost])
            moved = True

    if moved == False and x < 2:
        newMatrix = copy.deepcopy(matrix)
        newMatrix[x][y] = newMatrix[x+1][y]
        newMatrix[x+1][y] = 0
        childCost = costCal(newMatrix)
        if childCost < cost:
            matrix = newMatrix
            cost = childCost
            step = step+1
            info.append([newMatrix, matrix, "DOWN", step, cost])
            moved = True

    if moved == False and y > 0:
        newMatrix = copy.deepcopy(matrix)
        newMatrix[x][y] = newMatrix[x][y-1]
        newMatrix[x][y-1] = 0
        childCost = costCal(newMatrix)
        if childCost < cost:
            matrix = newMatrix
            cost = childCost
            step = step+1
            info.append([newMatrix, matrix, "LEFT", step, cost])
            moved = True

    if moved == False and y < 2:
        newMatrix = copy.deepcopy(matrix)
        newMatrix[x][y] = newMatrix[x][y+1]
        newMatrix[x][y+1] = 0
        childCost = costCal(newMatrix)
        if childCost < cost:
            matrix = newMatrix
            cost = childCost
            info.append([newMatrix, matrix, "RIGHT", step, cost])
            moved = True

    if moved == False:
        done = True
        print("KẾT QUẢ ")
        print("Start:")
        for row in info[0][0]:
            print(row)

        print("\n")

        print("Goal")
        for row in winMatrix:
            print(row)

        print("\n")

        print("CÁC BƯỚC DI CHUYỂN")
        for i in range(0, len(info)):
            currentState = info[i]
            currMatrix = currentState[0]
            currAct = currentState[2]
            currStep = currentState[3]
            currCost = currentState[4]

            print(f"Step {currStep}:   Action = {currAct}   Cost: {currCost}")
            for row in currMatrix:
                print(row)
            print("\n")
# Out:
# KẾT QUẢ
# Start:
# [1, 2, 3]
# [4, 6, 0]
# [7, 8, 5]
#
#
# Goal
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
#
#
# CÁC BƯỚC DI CHUYỂN
# Step 0: Action = None Cost: 3
# [1, 2, 3]
# [4, 6, 0]
# [7, 8, 5]
#
#
# Step 1: Action = DOWN Cost: 2
# [1, 2, 3]
# [4, 6, 5]
# [7, 8, 0]
