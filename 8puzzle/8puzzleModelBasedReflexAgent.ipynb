# %%
import random

winMatrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 0],
]

gameACTION = ["UP", "DOWN", "LEFT", "RIGHT"]

data = list(map(int, input("Nhập ma trận: ").split()))
matrix = [data[i:i+3] for i in range(0, 9, 3)]

def findZero(matrix):
    for i in range(3):
        for j in range(3):
            if matrix[i][j] == 0:
                x = i
                y = j
    return x, y

def getRules(x, y, gameACTION, lastAction):
    ruleAction = []
    if x > 0 and lastAction != "DOWN":
        ruleAction.append(gameACTION[0])
    if x < 2 and lastAction != "UP":
        ruleAction.append(gameACTION[1])
    if y > 0 and lastAction != "RIGHT":
        ruleAction.append(gameACTION[2])
    if y < 2 and lastAction != "LEFT":
        ruleAction.append(gameACTION[3])

    return ruleAction

def move(matrix, x, y, zeroAction):
    if zeroAction == "UP":
        matrix[x][y] = matrix[x-1][y]
        matrix[x-1][y] = 0
    elif zeroAction == "DOWN":
        matrix[x][y] = matrix[x+1][y]
        matrix[x+1][y] = 0
    elif zeroAction == "LEFT":
        matrix[x][y] = matrix[x][y-1]
        matrix[x][y-1] = 0
    elif zeroAction == "RIGHT":
        matrix[x][y] = matrix[x][y+1]
        matrix[x][y+1] = 0
    return matrix

count = 0
lastAction = ""
while (matrix != winMatrix and count < 1000):
    x, y = findZero(matrix)
    ruleAction = getRules(x, y, gameACTION, lastAction)
    zeroAction = random.choice(ruleAction)
    matrix = move(matrix, x, y, zeroAction)
    lastAction = zeroAction

    count += 1
    print("Bước", count, ":", zeroAction)
    for row in matrix:
        print(row)
    print()

if (matrix == winMatrix):
    print("Đã hoàn thành")
else:
    print("Dừng lại sau 1000 bước")
# Out:
# Bước 1 : LEFT
# [1, 2, 3]
# [4, 5, 6]
# [0, 7, 8]
#
# Bước 2 : UP
# [1, 2, 3]
# [0, 5, 6]
# [4, 7, 8]
#
# Bước 3 : RIGHT
# [1, 2, 3]
# [5, 0, 6]
# [4, 7, 8]
#
# Bước 4 : DOWN
# [1, 2, 3]
# [5, 7, 6]
# [4, 0, 8]
#
# Bước 5 : LEFT
# [1, 2, 3]
# [5, 7, 6]
# [0, 4, 8]
#
# Bước 6 : UP
# [1, 2, 3]
# [0, 7, 6]
# [5, 4, 8]
#
# Bước 7 : UP
# [0, 2, 3]
# [1, 7, 6]
# [5, 4, 8]
#
# Bước 8 : RIGHT
# [2, 0, 3]
# [1, 7, 6]
# [5, 4, 8]
#
# Bước 9 : RIGHT
# [2, 3, 0]
# [1, 7, 6]
# [5, 4, 8]
#
# Bước 10 : DOWN
# [2, 3, 6]
# [1, 7, 0]
# [5, 4, 8]
#
# Bước 11 : LEFT
# [2, 3, 6]
# [1, 0, 7]
# [5, 4, 8]
#
# Bước 12 : LEFT
# [2, 3, 6]
# [0, 1, 7]
# [5, 4, 8]
#
# Bước 13 : DOWN
# [2, 3, 6]
# [5, 1, 7]
# [0, 4, 8]
#
# Bước 14 : RIGHT
# [2, 3, 6]
# [5, 1, 7]
# [4, 0, 8]
#
# Bước 15 : RIGHT
# [2, 3, 6]
# [5, 1, 7]
# [4, 8, 0]
#
# Bước 16 : UP
# [2, 3, 6]
# [5, 1, 0]
# [4, 8, 7]
#
# Bước 17 : UP
# [2, 3, 0]
# [5, 1, 6]
# [4, 8, 7]
#
# Bước 18 : LEFT
# [2, 0, 3]
# [5, 1, 6]
# [4, 8, 7]
#
# Bước 19 : LEFT
# [0, 2, 3]
# [5, 1, 6]
# [4, 8, 7]
#
# Bước 20 : DOWN
# [5, 2, 3]
# [0, 1, 6]
# [4, 8, 7]
#
# Bước 21 : RIGHT
# [5, 2, 3]
# [1, 0, 6]
# [4, 8, 7]
#
# Bước 22 : DOWN
# [5, 2, 3]
# [1, 8, 6]
# [4, 0, 7]
#
# Bước 23 : LEFT
# [5, 2, 3]
# [1, 8, 6]
# [0, 4, 7]
#
# Bước 24 : UP
# [5, 2, 3]
# [0, 8, 6]
# [1, 4, 7]
#
# Bước 25 : RIGHT
# [5, 2, 3]
# [8, 0, 6]
# [1, 4, 7]
#
# Bước 26 : DOWN
# [5, 2, 3]
# [8, 4, 6]
# [1, 0, 7]
#
# Bước 27 : RIGHT
# [5, 2, 3]
# [8, 4, 6]
# [1, 7, 0]
#
# Bước 28 : UP
# [5, 2, 3]
# [8, 4, 0]
# [1, 7, 6]
#
# Bước 29 : UP
# [5, 2, 0]
# [8, 4, 3]
# [1, 7, 6]
#
# Bước 30 : LEFT
# [5, 0, 2]
# [8, 4, 3]
# [1, 7, 6]
#
# Bước 31 : DOWN
# [5, 4, 2]
# [8, 0, 3]
# [1, 7, 6]
#
# Bước 32 : DOWN
# [5, 4, 2]
# [8, 7, 3]
# [1, 0, 6]
#
# Bước 33 : RIGHT
# [5, 4, 2]
# [8, 7, 3]
# [1, 6, 0]
#
# Bước 34 : UP
# [5, 4, 2]
# [8, 7, 0]
# [1, 6, 3]
#
# Bước 35 : LEFT
# [5, 4, 2]
# [8, 0, 7]
# [1, 6, 3]
#
# Bước 36 : DOWN
# [5, 4, 2]
# [8, 6, 7]
# [1, 0, 3]
#
# Bước 37 : LEFT
# [5, 4, 2]
# [8, 6, 7]
# [0, 1, 3]
#
# Bước 38 : UP
# [5, 4, 2]
# [0, 6, 7]
# [8, 1, 3]
#
# Bước 39 : UP
# [0, 4, 2]
# [5, 6, 7]
# [8, 1, 3]
#
# Bước 40 : RIGHT
# [4, 0, 2]
# [5, 6, 7]
# [8, 1, 3]
#
# Bước 41 : RIGHT
# [4, 2, 0]
# [5, 6, 7]
# [8, 1, 3]
#
# Bước 42 : DOWN
# [4, 2, 7]
# [5, 6, 0]
# [8, 1, 3]
#
# Bước 43 : DOWN
# [4, 2, 7]
# [5, 6, 3]
# [8, 1, 0]
#
# Bước 44 : LEFT
# [4, 2, 7]
# [5, 6, 3]
# [8, 0, 1]
#
# Bước 45 : UP
# [4, 2, 7]
# [5, 0, 3]
# [8, 6, 1]
#
# Bước 46 : UP
# [4, 0, 7]
# [5, 2, 3]
# [8, 6, 1]
#
# Bước 47 : LEFT
# [0, 4, 7]
# [5, 2, 3]
# [8, 6, 1]
#
# Bước 48 : DOWN
# [5, 4, 7]
# [0, 2, 3]
# [8, 6, 1]
#
# Bước 49 : DOWN
# [5, 4, 7]
# [8, 2, 3]
# [0, 6, 1]
#
# Bước 50 : RIGHT
# [5, 4, 7]
# [8, 2, 3]
# [6, 0, 1]
#
# Bước 51 : RIGHT
# [5, 4, 7]
# [8, 2, 3]
# [6, 1, 0]
#
# Bước 52 : UP
# [5, 4, 7]
# [8, 2, 0]
# [6, 1, 3]
#
# Bước 53 : LEFT
# [5, 4, 7]
# [8, 0, 2]
# [6, 1, 3]
#
# Bước 54 : UP
# [5, 0, 7]
# [8, 4, 2]
# [6, 1, 3]
#
# Bước 55 : RIGHT
# [5, 7, 0]
# [8, 4, 2]
# [6, 1, 3]
#
# Bước 56 : DOWN
# [5, 7, 2]
# [8, 4, 0]
# [6, 1, 3]
#
# Bước 57 : DOWN
# [5, 7, 2]
# [8, 4, 3]
# [6, 1, 0]
#
# Bước 58 : LEFT
# [5, 7, 2]
# [8, 4, 3]
# [6, 0, 1]
#
# Bước 59 : UP
# [5, 7, 2]
# [8, 0, 3]
# [6, 4, 1]
#
# Bước 60 : RIGHT
# [5, 7, 2]
# [8, 3, 0]
# [6, 4, 1]
#
# Bước 61 : DOWN
# [5, 7, 2]
# [8, 3, 1]
# [6, 4, 0]
#
# Bước 62 : LEFT
# [5, 7, 2]
# [8, 3, 1]
# [6, 0, 4]
#
# Bước 63 : UP
# [5, 7, 2]
# [8, 0, 1]
# [6, 3, 4]
#
# Bước 64 : RIGHT
# [5, 7, 2]
# [8, 1, 0]
# [6, 3, 4]
#
# Bước 65 : UP
# [5, 7, 0]
# [8, 1, 2]
# [6, 3, 4]
#
# Bước 66 : LEFT
# [5, 0, 7]
# [8, 1, 2]
# [6, 3, 4]
#
# Bước 67 : LEFT
# [0, 5, 7]
# [8, 1, 2]
# [6, 3, 4]
#
# Bước 68 : DOWN
# [8, 5, 7]
# [0, 1, 2]
# [6, 3, 4]
#
# Bước 69 : RIGHT
# [8, 5, 7]
# [1, 0, 2]
# [6, 3, 4]
#
# Bước 70 : UP
# [8, 0, 7]
# [1, 5, 2]
# [6, 3, 4]
#
# Bước 71 : LEFT
# [0, 8, 7]
# [1, 5, 2]
# [6, 3, 4]
#
# Bước 72 : DOWN
# [1, 8, 7]
# [0, 5, 2]
# [6, 3, 4]
#
# Bước 73 : RIGHT
# [1, 8, 7]
# [5, 0, 2]
# [6, 3, 4]
#
# Bước 74 : DOWN
# [1, 8, 7]
# [5, 3, 2]
# [6, 0, 4]
#
# Bước 75 : LEFT
# [1, 8, 7]
# [5, 3, 2]
# [0, 6, 4]
#
# Bước 76 : UP
# [1, 8, 7]
# [0, 3, 2]
# [5, 6, 4]
#
# Bước 77 : UP
# [0, 8, 7]
# [1, 3, 2]
# [5, 6, 4]
#
# Bước 78 : RIGHT
# [8, 0, 7]
# [1, 3, 2]
# [5, 6, 4]
#
# Bước 79 : DOWN
# [8, 3, 7]
# [1, 0, 2]
# [5, 6, 4]
#
# Bước 80 : LEFT
# [8, 3, 7]
# [0, 1, 2]
# [5, 6, 4]
#
# Bước 81 : UP
# [0, 3, 7]
# [8, 1, 2]
# [5, 6, 4]
#
# Bước 82 : RIGHT
# [3, 0, 7]
# [8, 1, 2]
# [5, 6, 4]
#
# Bước 83 : RIGHT
# [3, 7, 0]
# [8, 1, 2]
# [5, 6, 4]
#
# Bước 84 : DOWN
# [3, 7, 2]
# [8, 1, 0]
# [5, 6, 4]
#
# Bước 85 : DOWN
# [3, 7, 2]
# [8, 1, 4]
# [5, 6, 0]
#
# Bước 86 : LEFT
# [3, 7, 2]
# [8, 1, 4]
# [5, 0, 6]
#
# Bước 87 : UP
# [3, 7, 2]
# [8, 0, 4]
# [5, 1, 6]
#
# Bước 88 : UP
# [3, 0, 2]
# [8, 7, 4]
# [5, 1, 6]
#
# Bước 89 : LEFT
# [0, 3, 2]
# [8, 7, 4]
# [5, 1, 6]
#
# Bước 90 : DOWN
# [8, 3, 2]
# [0, 7, 4]
# [5, 1, 6]
#
# Bước 91 : DOWN
# [8, 3, 2]
# [5, 7, 4]
# [0, 1, 6]
#
# Bước 92 : RIGHT
# [8, 3, 2]
# [5, 7, 4]
# [1, 0, 6]
#
# Bước 93 : UP
# [8, 3, 2]
# [5, 0, 4]
# [1, 7, 6]
#
# Bước 94 : UP
# [8, 0, 2]
# [5, 3, 4]
# [1, 7, 6]
#
# Bước 95 : RIGHT
# [8, 2, 0]
# [5, 3, 4]
# [1, 7, 6]
#
# Bước 96 : DOWN
# [8, 2, 4]
# [5, 3, 0]
# [1, 7, 6]
#
# Bước 97 : DOWN
# [8, 2, 4]
# [5, 3, 6]
# [1, 7, 0]
#
# Bước 98 : LEFT
# [8, 2, 4]
# [5, 3, 6]
# [1, 0, 7]
#
# Bước 99 : UP
# [8, 2, 4]
# [5, 0, 6]
# [1, 3, 7]
#
# Bước 100 : UP
# [8, 0, 4]
# [5, 2, 6]
# [1, 3, 7]
#
# Bước 101 : RIGHT
# [8, 4, 0]
# [5, 2, 6]
# [1, 3, 7]
#
# Bước 102 : DOWN
# [8, 4, 6]
# [5, 2, 0]
# [1, 3, 7]
#
# Bước 103 : DOWN
# [8, 4, 6]
# [5, 2, 7]
# [1, 3, 0]
#
# Bước 104 : LEFT
# [8, 4, 6]
# [5, 2, 7]
# [1, 0, 3]
#
# Bước 105 : UP
# [8, 4, 6]
# [5, 0, 7]
# [1, 2, 3]
#
# Bước 106 : LEFT
# [8, 4, 6]
# [0, 5, 7]
# [1, 2, 3]
#
# Bước 107 : UP
# [0, 4, 6]
# [8, 5, 7]
# [1, 2, 3]
#
# Bước 108 : RIGHT
# [4, 0, 6]
# [8, 5, 7]
# [1, 2, 3]
#
# Bước 109 : RIGHT
# [4, 6, 0]
# [8, 5, 7]
# [1, 2, 3]
#
# Bước 110 : DOWN
# [4, 6, 7]
# [8, 5, 0]
# [1, 2, 3]
#
# Bước 111 : LEFT
# [4, 6, 7]
# [8, 0, 5]
# [1, 2, 3]
#
# Bước 112 : UP
# [4, 0, 7]
# [8, 6, 5]
# [1, 2, 3]
#
# Bước 113 : LEFT
# [0, 4, 7]
# [8, 6, 5]
# [1, 2, 3]
#
# Bước 114 : DOWN
# [8, 4, 7]
# [0, 6, 5]
# [1, 2, 3]
#
# Bước 115 : DOWN
# [8, 4, 7]
# [1, 6, 5]
# [0, 2, 3]
#
# Bước 116 : RIGHT
# [8, 4, 7]
# [1, 6, 5]
# [2, 0, 3]
#
# Bước 117 : RIGHT
# [8, 4, 7]
# [1, 6, 5]
# [2, 3, 0]
#
# Bước 118 : UP
# [8, 4, 7]
# [1, 6, 0]
# [2, 3, 5]
#
# Bước 119 : UP
# [8, 4, 0]
# [1, 6, 7]
# [2, 3, 5]
#
# Bước 120 : LEFT
# [8, 0, 4]
# [1, 6, 7]
# [2, 3, 5]
#
# Bước 121 : LEFT
# [0, 8, 4]
# [1, 6, 7]
# [2, 3, 5]
#
# Bước 122 : DOWN
# [1, 8, 4]
# [0, 6, 7]
# [2, 3, 5]
#
# Bước 123 : RIGHT
# [1, 8, 4]
# [6, 0, 7]
# [2, 3, 5]
#
# Bước 124 : RIGHT
# [1, 8, 4]
# [6, 7, 0]
# [2, 3, 5]
#
# Bước 125 : DOWN
# [1, 8, 4]
# [6, 7, 5]
# [2, 3, 0]
#
# Bước 126 : LEFT
# [1, 8, 4]
# [6, 7, 5]
# [2, 0, 3]
#
# Bước 127 : UP
# [1, 8, 4]
# [6, 0, 5]
# [2, 7, 3]
#
# Bước 128 : UP
# [1, 0, 4]
# [6, 8, 5]
# [2, 7, 3]
#
# Bước 129 : LEFT
# [0, 1, 4]
# [6, 8, 5]
# [2, 7, 3]
#
# Bước 130 : DOWN
# [6, 1, 4]
# [0, 8, 5]
# [2, 7, 3]
#
# Bước 131 : RIGHT
# [6, 1, 4]
# [8, 0, 5]
# [2, 7, 3]
#
# Bước 132 : RIGHT
# [6, 1, 4]
# [8, 5, 0]
# [2, 7, 3]
#
# Bước 133 : UP
# [6, 1, 0]
# [8, 5, 4]
# [2, 7, 3]
#
# Bước 134 : LEFT
# [6, 0, 1]
# [8, 5, 4]
# [2, 7, 3]
#
# Bước 135 : LEFT
# [0, 6, 1]
# [8, 5, 4]
# [2, 7, 3]
#
# Bước 136 : DOWN
# [8, 6, 1]
# [0, 5, 4]
# [2, 7, 3]
#
# Bước 137 : DOWN
# [8, 6, 1]
# [2, 5, 4]
# [0, 7, 3]
#
# Bước 138 : RIGHT
# [8, 6, 1]
# [2, 5, 4]
# [7, 0, 3]
#
# Bước 139 : UP
# [8, 6, 1]
# [2, 0, 4]
# [7, 5, 3]
#
# Bước 140 : LEFT
# [8, 6, 1]
# [0, 2, 4]
# [7, 5, 3]
#
# Bước 141 : UP
# [0, 6, 1]
# [8, 2, 4]
# [7, 5, 3]
#
# Bước 142 : RIGHT
# [6, 0, 1]
# [8, 2, 4]
# [7, 5, 3]
#
# Bước 143 : RIGHT
# [6, 1, 0]
# [8, 2, 4]
# [7, 5, 3]
#
# Bước 144 : DOWN
# [6, 1, 4]
# [8, 2, 0]
# [7, 5, 3]
#
# Bước 145 : LEFT
# [6, 1, 4]
# [8, 0, 2]
# [7, 5, 3]
#
# Bước 146 : UP
# [6, 0, 4]
# [8, 1, 2]
# [7, 5, 3]
#
# Bước 147 : RIGHT
# [6, 4, 0]
# [8, 1, 2]
# [7, 5, 3]
#
# Bước 148 : DOWN
# [6, 4, 2]
# [8, 1, 0]
# [7, 5, 3]
#
# Bước 149 : LEFT
# [6, 4, 2]
# [8, 0, 1]
# [7, 5, 3]
#
# Bước 150 : DOWN
# [6, 4, 2]
# [8, 5, 1]
# [7, 0, 3]
#
# Bước 151 : LEFT
# [6, 4, 2]
# [8, 5, 1]
# [0, 7, 3]
#
# Bước 152 : UP
# [6, 4, 2]
# [0, 5, 1]
# [8, 7, 3]
#
# Bước 153 : UP
# [0, 4, 2]
# [6, 5, 1]
# [8, 7, 3]
#
# Bước 154 : RIGHT
# [4, 0, 2]
# [6, 5, 1]
# [8, 7, 3]
#
# Bước 155 : RIGHT
# [4, 2, 0]
# [6, 5, 1]
# [8, 7, 3]
#
# Bước 156 : DOWN
# [4, 2, 1]
# [6, 5, 0]
# [8, 7, 3]
#
# Bước 157 : LEFT
# [4, 2, 1]
# [6, 0, 5]
# [8, 7, 3]
#
# Bước 158 : DOWN
# [4, 2, 1]
# [6, 7, 5]
# [8, 0, 3]
#
# Bước 159 : LEFT
# [4, 2, 1]
# [6, 7, 5]
# [0, 8, 3]
#
# Bước 160 : UP
# [4, 2, 1]
# [0, 7, 5]
# [6, 8, 3]
#
# Bước 161 : RIGHT
# [4, 2, 1]
# [7, 0, 5]
# [6, 8, 3]
#
# Bước 162 : UP
# [4, 0, 1]
# [7, 2, 5]
# [6, 8, 3]
#
# Bước 163 : RIGHT
# [4, 1, 0]
# [7, 2, 5]
# [6, 8, 3]
#
# Bước 164 : DOWN
# [4, 1, 5]
# [7, 2, 0]
# [6, 8, 3]
#
# Bước 165 : LEFT
# [4, 1, 5]
# [7, 0, 2]
# [6, 8, 3]
#
# Bước 166 : DOWN
# [4, 1, 5]
# [7, 8, 2]
# [6, 0, 3]
#
# Bước 167 : RIGHT
# [4, 1, 5]
# [7, 8, 2]
# [6, 3, 0]
#
# Bước 168 : UP
# [4, 1, 5]
# [7, 8, 0]
# [6, 3, 2]
#
# Bước 169 : LEFT
# [4, 1, 5]
# [7, 0, 8]
# [6, 3, 2]
#
# Bước 170 : UP
# [4, 0, 5]
# [7, 1, 8]
# [6, 3, 2]
#
# Bước 171 : RIGHT
# [4, 5, 0]
# [7, 1, 8]
# [6, 3, 2]
#
# Bước 172 : DOWN
# [4, 5, 8]
# [7, 1, 0]
# [6, 3, 2]
#
# Bước 173 : DOWN
# [4, 5, 8]
# [7, 1, 2]
# [6, 3, 0]
#
# Bước 174 : LEFT
# [4, 5, 8]
# [7, 1, 2]
# [6, 0, 3]
#
# Bước 175 : LEFT
# [4, 5, 8]
# [7, 1, 2]
# [0, 6, 3]
#
# Bước 176 : UP
# [4, 5, 8]
# [0, 1, 2]
# [7, 6, 3]
#
# Bước 177 : RIGHT
# [4, 5, 8]
# [1, 0, 2]
# [7, 6, 3]
#
# Bước 178 : RIGHT
# [4, 5, 8]
# [1, 2, 0]
# [7, 6, 3]
#
# Bước 179 : DOWN
# [4, 5, 8]
# [1, 2, 3]
# [7, 6, 0]
#
# Bước 180 : LEFT
# [4, 5, 8]
# [1, 2, 3]
# [7, 0, 6]
#
# Bước 181 : LEFT
# [4, 5, 8]
# [1, 2, 3]
# [0, 7, 6]
#
# Bước 182 : UP
# [4, 5, 8]
# [0, 2, 3]
# [1, 7, 6]
#
# Bước 183 : RIGHT
# [4, 5, 8]
# [2, 0, 3]
# [1, 7, 6]
#
# Bước 184 : UP
# [4, 0, 8]
# [2, 5, 3]
# [1, 7, 6]
#
# Bước 185 : RIGHT
# [4, 8, 0]
# [2, 5, 3]
# [1, 7, 6]
#
# Bước 186 : DOWN
# [4, 8, 3]
# [2, 5, 0]
# [1, 7, 6]
#
# Bước 187 : LEFT
# [4, 8, 3]
# [2, 0, 5]
# [1, 7, 6]
#
# Bước 188 : UP
# [4, 0, 3]
# [2, 8, 5]
# [1, 7, 6]
#
# Bước 189 : RIGHT
# [4, 3, 0]
# [2, 8, 5]
# [1, 7, 6]
#
# Bước 190 : DOWN
# [4, 3, 5]
# [2, 8, 0]
# [1, 7, 6]
#
# Bước 191 : LEFT
# [4, 3, 5]
# [2, 0, 8]
# [1, 7, 6]
#
# Bước 192 : DOWN
# [4, 3, 5]
# [2, 7, 8]
# [1, 0, 6]
#
# Bước 193 : LEFT
# [4, 3, 5]
# [2, 7, 8]
# [0, 1, 6]
#
# Bước 194 : UP
# [4, 3, 5]
# [0, 7, 8]
# [2, 1, 6]
#
# Bước 195 : UP
# [0, 3, 5]
# [4, 7, 8]
# [2, 1, 6]
#
# Bước 196 : RIGHT
# [3, 0, 5]
# [4, 7, 8]
# [2, 1, 6]
#
# Bước 197 : DOWN
# [3, 7, 5]
# [4, 0, 8]
# [2, 1, 6]
#
# Bước 198 : RIGHT
# [3, 7, 5]
# [4, 8, 0]
# [2, 1, 6]
#
# Bước 199 : DOWN
# [3, 7, 5]
# [4, 8, 6]
# [2, 1, 0]
#
# Bước 200 : LEFT
# [3, 7, 5]
# [4, 8, 6]
# [2, 0, 1]
#
# Bước 201 : UP
# [3, 7, 5]
# [4, 0, 6]
# [2, 8, 1]
#
# Bước 202 : LEFT
# [3, 7, 5]
# [0, 4, 6]
# [2, 8, 1]
#
# Bước 203 : UP
# [0, 7, 5]
# [3, 4, 6]
# [2, 8, 1]
#
# Bước 204 : RIGHT
# [7, 0, 5]
# [3, 4, 6]
# [2, 8, 1]
#
# Bước 205 : RIGHT
# [7, 5, 0]
# [3, 4, 6]
# [2, 8, 1]
#
# Bước 206 : DOWN
# [7, 5, 6]
# [3, 4, 0]
# [2, 8, 1]
#
# Bước 207 : LEFT
# [7, 5, 6]
# [3, 0, 4]
# [2, 8, 1]
#
# Bước 208 : DOWN
# [7, 5, 6]
# [3, 8, 4]
# [2, 0, 1]
#
# Bước 209 : LEFT
# [7, 5, 6]
# [3, 8, 4]
# [0, 2, 1]
#
# Bước 210 : UP
# [7, 5, 6]
# [0, 8, 4]
# [3, 2, 1]
#
# Bước 211 : RIGHT
# [7, 5, 6]
# [8, 0, 4]
# [3, 2, 1]
#
# Bước 212 : DOWN
# [7, 5, 6]
# [8, 2, 4]
# [3, 0, 1]
#
# Bước 213 : LEFT
# [7, 5, 6]
# [8, 2, 4]
# [0, 3, 1]
#
# Bước 214 : UP
# [7, 5, 6]
# [0, 2, 4]
# [8, 3, 1]
#
# Bước 215 : UP
# [0, 5, 6]
# [7, 2, 4]
# [8, 3, 1]
#
# Bước 216 : RIGHT
# [5, 0, 6]
# [7, 2, 4]
# [8, 3, 1]
#
# Bước 217 : DOWN
# [5, 2, 6]
# [7, 0, 4]
# [8, 3, 1]
#
# Bước 218 : RIGHT
# [5, 2, 6]
# [7, 4, 0]
# [8, 3, 1]
#
# Bước 219 : DOWN
# [5, 2, 6]
# [7, 4, 1]
# [8, 3, 0]
#
# Bước 220 : LEFT
# [5, 2, 6]
# [7, 4, 1]
# [8, 0, 3]
#
# Bước 221 : UP
# [5, 2, 6]
# [7, 0, 1]
# [8, 4, 3]
#
# Bước 222 : RIGHT
# [5, 2, 6]
# [7, 1, 0]
# [8, 4, 3]
#
# Bước 223 : UP
# [5, 2, 0]
# [7, 1, 6]
# [8, 4, 3]
#
# Bước 224 : LEFT
# [5, 0, 2]
# [7, 1, 6]
# [8, 4, 3]
#
# Bước 225 : LEFT
# [0, 5, 2]
# [7, 1, 6]
# [8, 4, 3]
#
# Bước 226 : DOWN
# [7, 5, 2]
# [0, 1, 6]
# [8, 4, 3]
#
# Bước 227 : RIGHT
# [7, 5, 2]
# [1, 0, 6]
# [8, 4, 3]
#
# Bước 228 : UP
# [7, 0, 2]
# [1, 5, 6]
# [8, 4, 3]
#
# Bước 229 : RIGHT
# [7, 2, 0]
# [1, 5, 6]
# [8, 4, 3]
#
# Bước 230 : DOWN
# [7, 2, 6]
# [1, 5, 0]
# [8, 4, 3]
#
# Bước 231 : DOWN
# [7, 2, 6]
# [1, 5, 3]
# [8, 4, 0]
#
# Bước 232 : LEFT
# [7, 2, 6]
# [1, 5, 3]
# [8, 0, 4]
#
# Bước 233 : UP
# [7, 2, 6]
# [1, 0, 3]
# [8, 5, 4]
#
# Bước 234 : LEFT
# [7, 2, 6]
# [0, 1, 3]
# [8, 5, 4]
#
# Bước 235 : DOWN
# [7, 2, 6]
# [8, 1, 3]
# [0, 5, 4]
#
# Bước 236 : RIGHT
# [7, 2, 6]
# [8, 1, 3]
# [5, 0, 4]
#
# Bước 237 : UP
# [7, 2, 6]
# [8, 0, 3]
# [5, 1, 4]
#
# Bước 238 : UP
# [7, 0, 6]
# [8, 2, 3]
# [5, 1, 4]
#
# Bước 239 : LEFT
# [0, 7, 6]
# [8, 2, 3]
# [5, 1, 4]
#
# Bước 240 : DOWN
# [8, 7, 6]
# [0, 2, 3]
# [5, 1, 4]
#
# Bước 241 : RIGHT
# [8, 7, 6]
# [2, 0, 3]
# [5, 1, 4]
#
# Bước 242 : RIGHT
# [8, 7, 6]
# [2, 3, 0]
# [5, 1, 4]
#
# Bước 243 : UP
# [8, 7, 0]
# [2, 3, 6]
# [5, 1, 4]
#
# Bước 244 : LEFT
# [8, 0, 7]
# [2, 3, 6]
# [5, 1, 4]
#
# Bước 245 : DOWN
# [8, 3, 7]
# [2, 0, 6]
# [5, 1, 4]
#
# Bước 246 : DOWN
# [8, 3, 7]
# [2, 1, 6]
# [5, 0, 4]
#
# Bước 247 : RIGHT
# [8, 3, 7]
# [2, 1, 6]
# [5, 4, 0]
#
# Bước 248 : UP
# [8, 3, 7]
# [2, 1, 0]
# [5, 4, 6]
#
# Bước 249 : UP
# [8, 3, 0]
# [2, 1, 7]
# [5, 4, 6]
#
# Bước 250 : LEFT
# [8, 0, 3]
# [2, 1, 7]
# [5, 4, 6]
#
# Bước 251 : LEFT
# [0, 8, 3]
# [2, 1, 7]
# [5, 4, 6]
#
# Bước 252 : DOWN
# [2, 8, 3]
# [0, 1, 7]
# [5, 4, 6]
#
# Bước 253 : DOWN
# [2, 8, 3]
# [5, 1, 7]
# [0, 4, 6]
#
# Bước 254 : RIGHT
# [2, 8, 3]
# [5, 1, 7]
# [4, 0, 6]
#
# Bước 255 : UP
# [2, 8, 3]
# [5, 0, 7]
# [4, 1, 6]
#
# Bước 256 : UP
# [2, 0, 3]
# [5, 8, 7]
# [4, 1, 6]
#
# Bước 257 : LEFT
# [0, 2, 3]
# [5, 8, 7]
# [4, 1, 6]
#
# Bước 258 : DOWN
# [5, 2, 3]
# [0, 8, 7]
# [4, 1, 6]
#
# Bước 259 : DOWN
# [5, 2, 3]
# [4, 8, 7]
# [0, 1, 6]
#
# Bước 260 : RIGHT
# [5, 2, 3]
# [4, 8, 7]
# [1, 0, 6]
#
# Bước 261 : RIGHT
# [5, 2, 3]
# [4, 8, 7]
# [1, 6, 0]
#
# Bước 262 : UP
# [5, 2, 3]
# [4, 8, 0]
# [1, 6, 7]
#
# Bước 263 : LEFT
# [5, 2, 3]
# [4, 0, 8]
# [1, 6, 7]
#
# Bước 264 : LEFT
# [5, 2, 3]
# [0, 4, 8]
# [1, 6, 7]
#
# Bước 265 : UP
# [0, 2, 3]
# [5, 4, 8]
# [1, 6, 7]
#
# Bước 266 : RIGHT
# [2, 0, 3]
# [5, 4, 8]
# [1, 6, 7]
#
# Bước 267 : DOWN
# [2, 4, 3]
# [5, 0, 8]
# [1, 6, 7]
#
# Bước 268 : LEFT
# [2, 4, 3]
# [0, 5, 8]
# [1, 6, 7]
#
# Bước 269 : DOWN
# [2, 4, 3]
# [1, 5, 8]
# [0, 6, 7]
#
# Bước 270 : RIGHT
# [2, 4, 3]
# [1, 5, 8]
# [6, 0, 7]
#
# Bước 271 : RIGHT
# [2, 4, 3]
# [1, 5, 8]
# [6, 7, 0]
#
# Bước 272 : UP
# [2, 4, 3]
# [1, 5, 0]
# [6, 7, 8]
#
# Bước 273 : LEFT
# [2, 4, 3]
# [1, 0, 5]
# [6, 7, 8]
#
# Bước 274 : LEFT
# [2, 4, 3]
# [0, 1, 5]
# [6, 7, 8]
#
# Bước 275 : DOWN
# [2, 4, 3]
# [6, 1, 5]
# [0, 7, 8]
#
# Bước 276 : RIGHT
# [2, 4, 3]
# [6, 1, 5]
# [7, 0, 8]
#
# Bước 277 : RIGHT
# [2, 4, 3]
# [6, 1, 5]
# [7, 8, 0]
#
# Bước 278 : UP
# [2, 4, 3]
# [6, 1, 0]
# [7, 8, 5]
#
# Bước 279 : LEFT
# [2, 4, 3]
# [6, 0, 1]
# [7, 8, 5]
#
# Bước 280 : DOWN
# [2, 4, 3]
# [6, 8, 1]
# [7, 0, 5]
#
# Bước 281 : LEFT
# [2, 4, 3]
# [6, 8, 1]
# [0, 7, 5]
#
# Bước 282 : UP
# [2, 4, 3]
# [0, 8, 1]
# [6, 7, 5]
#
# Bước 283 : RIGHT
# [2, 4, 3]
# [8, 0, 1]
# [6, 7, 5]
#
# Bước 284 : RIGHT
# [2, 4, 3]
# [8, 1, 0]
# [6, 7, 5]
#
# Bước 285 : DOWN
# [2, 4, 3]
# [8, 1, 5]
# [6, 7, 0]
#
# Bước 286 : LEFT
# [2, 4, 3]
# [8, 1, 5]
# [6, 0, 7]
#
# Bước 287 : LEFT
# [2, 4, 3]
# [8, 1, 5]
# [0, 6, 7]
#
# Bước 288 : UP
# [2, 4, 3]
# [0, 1, 5]
# [8, 6, 7]
#
# Bước 289 : UP
# [0, 4, 3]
# [2, 1, 5]
# [8, 6, 7]
#
# Bước 290 : RIGHT
# [4, 0, 3]
# [2, 1, 5]
# [8, 6, 7]
#
# Bước 291 : RIGHT
# [4, 3, 0]
# [2, 1, 5]
# [8, 6, 7]
#
# Bước 292 : DOWN
# [4, 3, 5]
# [2, 1, 0]
# [8, 6, 7]
#
# Bước 293 : LEFT
# [4, 3, 5]
# [2, 0, 1]
# [8, 6, 7]
#
# Bước 294 : DOWN
# [4, 3, 5]
# [2, 6, 1]
# [8, 0, 7]
#
# Bước 295 : RIGHT
# [4, 3, 5]
# [2, 6, 1]
# [8, 7, 0]
#
# Bước 296 : UP
# [4, 3, 5]
# [2, 6, 0]
# [8, 7, 1]
#
# Bước 297 : UP
# [4, 3, 0]
# [2, 6, 5]
# [8, 7, 1]
#
# Bước 298 : LEFT
# [4, 0, 3]
# [2, 6, 5]
# [8, 7, 1]
#
# Bước 299 : LEFT
# [0, 4, 3]
# [2, 6, 5]
# [8, 7, 1]
#
# Bước 300 : DOWN
# [2, 4, 3]
# [0, 6, 5]
# [8, 7, 1]
#
# Bước 301 : DOWN
# [2, 4, 3]
# [8, 6, 5]
# [0, 7, 1]
#
# Bước 302 : RIGHT
# [2, 4, 3]
# [8, 6, 5]
# [7, 0, 1]
#
# Bước 303 : RIGHT
# [2, 4, 3]
# [8, 6, 5]
# [7, 1, 0]
#
# Bước 304 : UP
# [2, 4, 3]
# [8, 6, 0]
# [7, 1, 5]
#
# Bước 305 : UP
# [2, 4, 0]
# [8, 6, 3]
# [7, 1, 5]
#
# Bước 306 : LEFT
# [2, 0, 4]
# [8, 6, 3]
# [7, 1, 5]
#
# Bước 307 : DOWN
# [2, 6, 4]
# [8, 0, 3]
# [7, 1, 5]
#
# Bước 308 : DOWN
# [2, 6, 4]
# [8, 1, 3]
# [7, 0, 5]
#
# Bước 309 : LEFT
# [2, 6, 4]
# [8, 1, 3]
# [0, 7, 5]
#
# Bước 310 : UP
# [2, 6, 4]
# [0, 1, 3]
# [8, 7, 5]
#
# Bước 311 : RIGHT
# [2, 6, 4]
# [1, 0, 3]
# [8, 7, 5]
#
# Bước 312 : UP
# [2, 0, 4]
# [1, 6, 3]
# [8, 7, 5]
#
# Bước 313 : LEFT
# [0, 2, 4]
# [1, 6, 3]
# [8, 7, 5]
#
# Bước 314 : DOWN
# [1, 2, 4]
# [0, 6, 3]
# [8, 7, 5]
#
# Bước 315 : DOWN
# [1, 2, 4]
# [8, 6, 3]
# [0, 7, 5]
#
# Bước 316 : RIGHT
# [1, 2, 4]
# [8, 6, 3]
# [7, 0, 5]
#
# Bước 317 : UP
# [1, 2, 4]
# [8, 0, 3]
# [7, 6, 5]
#
# Bước 318 : LEFT
# [1, 2, 4]
# [0, 8, 3]
# [7, 6, 5]
#
# Bước 319 : DOWN
# [1, 2, 4]
# [7, 8, 3]
# [0, 6, 5]
#
# Bước 320 : RIGHT
# [1, 2, 4]
# [7, 8, 3]
# [6, 0, 5]
#
# Bước 321 : UP
# [1, 2, 4]
# [7, 0, 3]
# [6, 8, 5]
#
# Bước 322 : LEFT
# [1, 2, 4]
# [0, 7, 3]
# [6, 8, 5]
#
# Bước 323 : DOWN
# [1, 2, 4]
# [6, 7, 3]
# [0, 8, 5]
#
# Bước 324 : RIGHT
# [1, 2, 4]
# [6, 7, 3]
# [8, 0, 5]
#
# Bước 325 : UP
# [1, 2, 4]
# [6, 0, 3]
# [8, 7, 5]
#
# Bước 326 : UP
# [1, 0, 4]
# [6, 2, 3]
# [8, 7, 5]
#
# Bước 327 : LEFT
# [0, 1, 4]
# [6, 2, 3]
# [8, 7, 5]
#
# Bước 328 : DOWN
# [6, 1, 4]
# [0, 2, 3]
# [8, 7, 5]
#
# Bước 329 : RIGHT
# [6, 1, 4]
# [2, 0, 3]
# [8, 7, 5]
#
# Bước 330 : RIGHT
# [6, 1, 4]
# [2, 3, 0]
# [8, 7, 5]
#
# Bước 331 : DOWN
# [6, 1, 4]
# [2, 3, 5]
# [8, 7, 0]
#
# Bước 332 : LEFT
# [6, 1, 4]
# [2, 3, 5]
# [8, 0, 7]
#
# Bước 333 : UP
# [6, 1, 4]
# [2, 0, 5]
# [8, 3, 7]
#
# Bước 334 : LEFT
# [6, 1, 4]
# [0, 2, 5]
# [8, 3, 7]
#
# Bước 335 : DOWN
# [6, 1, 4]
# [8, 2, 5]
# [0, 3, 7]
#
# Bước 336 : RIGHT
# [6, 1, 4]
# [8, 2, 5]
# [3, 0, 7]
#
# Bước 337 : UP
# [6, 1, 4]
# [8, 0, 5]
# [3, 2, 7]
#
# Bước 338 : RIGHT
# [6, 1, 4]
# [8, 5, 0]
# [3, 2, 7]
#
# Bước 339 : UP
# [6, 1, 0]
# [8, 5, 4]
# [3, 2, 7]
#
# Bước 340 : LEFT
# [6, 0, 1]
# [8, 5, 4]
# [3, 2, 7]
#
# Bước 341 : LEFT
# [0, 6, 1]
# [8, 5, 4]
# [3, 2, 7]
#
# Bước 342 : DOWN
# [8, 6, 1]
# [0, 5, 4]
# [3, 2, 7]
#
# Bước 343 : RIGHT
# [8, 6, 1]
# [5, 0, 4]
# [3, 2, 7]
#
# Bước 344 : RIGHT
# [8, 6, 1]
# [5, 4, 0]
# [3, 2, 7]
#
# Bước 345 : DOWN
# [8, 6, 1]
# [5, 4, 7]
# [3, 2, 0]
#
# Bước 346 : LEFT
# [8, 6, 1]
# [5, 4, 7]
# [3, 0, 2]
#
# Bước 347 : UP
# [8, 6, 1]
# [5, 0, 7]
# [3, 4, 2]
#
# Bước 348 : UP
# [8, 0, 1]
# [5, 6, 7]
# [3, 4, 2]
#
# Bước 349 : RIGHT
# [8, 1, 0]
# [5, 6, 7]
# [3, 4, 2]
#
# Bước 350 : DOWN
# [8, 1, 7]
# [5, 6, 0]
# [3, 4, 2]
#
# Bước 351 : LEFT
# [8, 1, 7]
# [5, 0, 6]
# [3, 4, 2]
#
# Bước 352 : UP
# [8, 0, 7]
# [5, 1, 6]
# [3, 4, 2]
#
# Bước 353 : RIGHT
# [8, 7, 0]
# [5, 1, 6]
# [3, 4, 2]
#
# Bước 354 : DOWN
# [8, 7, 6]
# [5, 1, 0]
# [3, 4, 2]
#
# Bước 355 : LEFT
# [8, 7, 6]
# [5, 0, 1]
# [3, 4, 2]
#
# Bước 356 : DOWN
# [8, 7, 6]
# [5, 4, 1]
# [3, 0, 2]
#
# Bước 357 : RIGHT
# [8, 7, 6]
# [5, 4, 1]
# [3, 2, 0]
#
# Bước 358 : UP
# [8, 7, 6]
# [5, 4, 0]
# [3, 2, 1]
#
# Bước 359 : UP
# [8, 7, 0]
# [5, 4, 6]
# [3, 2, 1]
#
# Bước 360 : LEFT
# [8, 0, 7]
# [5, 4, 6]
# [3, 2, 1]
#
# Bước 361 : LEFT
# [0, 8, 7]
# [5, 4, 6]
# [3, 2, 1]
#
# Bước 362 : DOWN
# [5, 8, 7]
# [0, 4, 6]
# [3, 2, 1]
#
# Bước 363 : RIGHT
# [5, 8, 7]
# [4, 0, 6]
# [3, 2, 1]
#
# Bước 364 : DOWN
# [5, 8, 7]
# [4, 2, 6]
# [3, 0, 1]
#
# Bước 365 : LEFT
# [5, 8, 7]
# [4, 2, 6]
# [0, 3, 1]
#
# Bước 366 : UP
# [5, 8, 7]
# [0, 2, 6]
# [4, 3, 1]
#
# Bước 367 : RIGHT
# [5, 8, 7]
# [2, 0, 6]
# [4, 3, 1]
#
# Bước 368 : RIGHT
# [5, 8, 7]
# [2, 6, 0]
# [4, 3, 1]
#
# Bước 369 : DOWN
# [5, 8, 7]
# [2, 6, 1]
# [4, 3, 0]
#
# Bước 370 : LEFT
# [5, 8, 7]
# [2, 6, 1]
# [4, 0, 3]
#
# Bước 371 : UP
# [5, 8, 7]
# [2, 0, 1]
# [4, 6, 3]
#
# Bước 372 : RIGHT
# [5, 8, 7]
# [2, 1, 0]
# [4, 6, 3]
#
# Bước 373 : UP
# [5, 8, 0]
# [2, 1, 7]
# [4, 6, 3]
#
# Bước 374 : LEFT
# [5, 0, 8]
# [2, 1, 7]
# [4, 6, 3]
#
# Bước 375 : LEFT
# [0, 5, 8]
# [2, 1, 7]
# [4, 6, 3]
#
# Bước 376 : DOWN
# [2, 5, 8]
# [0, 1, 7]
# [4, 6, 3]
#
# Bước 377 : DOWN
# [2, 5, 8]
# [4, 1, 7]
# [0, 6, 3]
#
# Bước 378 : RIGHT
# [2, 5, 8]
# [4, 1, 7]
# [6, 0, 3]
#
# Bước 379 : UP
# [2, 5, 8]
# [4, 0, 7]
# [6, 1, 3]
#
# Bước 380 : LEFT
# [2, 5, 8]
# [0, 4, 7]
# [6, 1, 3]
#
# Bước 381 : UP
# [0, 5, 8]
# [2, 4, 7]
# [6, 1, 3]
#
# Bước 382 : RIGHT
# [5, 0, 8]
# [2, 4, 7]
# [6, 1, 3]
#
# Bước 383 : RIGHT
# [5, 8, 0]
# [2, 4, 7]
# [6, 1, 3]
#
# Bước 384 : DOWN
# [5, 8, 7]
# [2, 4, 0]
# [6, 1, 3]
#
# Bước 385 : LEFT
# [5, 8, 7]
# [2, 0, 4]
# [6, 1, 3]
#
# Bước 386 : DOWN
# [5, 8, 7]
# [2, 1, 4]
# [6, 0, 3]
#
# Bước 387 : LEFT
# [5, 8, 7]
# [2, 1, 4]
# [0, 6, 3]
#
# Bước 388 : UP
# [5, 8, 7]
# [0, 1, 4]
# [2, 6, 3]
#
# Bước 389 : UP
# [0, 8, 7]
# [5, 1, 4]
# [2, 6, 3]
#
# Bước 390 : RIGHT
# [8, 0, 7]
# [5, 1, 4]
# [2, 6, 3]
#
# Bước 391 : DOWN
# [8, 1, 7]
# [5, 0, 4]
# [2, 6, 3]
#
# Bước 392 : RIGHT
# [8, 1, 7]
# [5, 4, 0]
# [2, 6, 3]
#
# Bước 393 : UP
# [8, 1, 0]
# [5, 4, 7]
# [2, 6, 3]
#
# Bước 394 : LEFT
# [8, 0, 1]
# [5, 4, 7]
# [2, 6, 3]
#
# Bước 395 : LEFT
# [0, 8, 1]
# [5, 4, 7]
# [2, 6, 3]
#
# Bước 396 : DOWN
# [5, 8, 1]
# [0, 4, 7]
# [2, 6, 3]
#
# Bước 397 : RIGHT
# [5, 8, 1]
# [4, 0, 7]
# [2, 6, 3]
#
# Bước 398 : UP
# [5, 0, 1]
# [4, 8, 7]
# [2, 6, 3]
#
# Bước 399 : RIGHT
# [5, 1, 0]
# [4, 8, 7]
# [2, 6, 3]
#
# Bước 400 : DOWN
# [5, 1, 7]
# [4, 8, 0]
# [2, 6, 3]
#
# Bước 401 : DOWN
# [5, 1, 7]
# [4, 8, 3]
# [2, 6, 0]
#
# Bước 402 : LEFT
# [5, 1, 7]
# [4, 8, 3]
# [2, 0, 6]
#
# Bước 403 : LEFT
# [5, 1, 7]
# [4, 8, 3]
# [0, 2, 6]
#
# Bước 404 : UP
# [5, 1, 7]
# [0, 8, 3]
# [4, 2, 6]
#
# Bước 405 : UP
# [0, 1, 7]
# [5, 8, 3]
# [4, 2, 6]
#
# Bước 406 : RIGHT
# [1, 0, 7]
# [5, 8, 3]
# [4, 2, 6]
#
# Bước 407 : DOWN
# [1, 8, 7]
# [5, 0, 3]
# [4, 2, 6]
#
# Bước 408 : LEFT
# [1, 8, 7]
# [0, 5, 3]
# [4, 2, 6]
#
# Bước 409 : UP
# [0, 8, 7]
# [1, 5, 3]
# [4, 2, 6]
#
# Bước 410 : RIGHT
# [8, 0, 7]
# [1, 5, 3]
# [4, 2, 6]
#
# Bước 411 : DOWN
# [8, 5, 7]
# [1, 0, 3]
# [4, 2, 6]
#
# Bước 412 : LEFT
# [8, 5, 7]
# [0, 1, 3]
# [4, 2, 6]
#
# Bước 413 : DOWN
# [8, 5, 7]
# [4, 1, 3]
# [0, 2, 6]
#
# Bước 414 : RIGHT
# [8, 5, 7]
# [4, 1, 3]
# [2, 0, 6]
#
# Bước 415 : RIGHT
# [8, 5, 7]
# [4, 1, 3]
# [2, 6, 0]
#
# Bước 416 : UP
# [8, 5, 7]
# [4, 1, 0]
# [2, 6, 3]
#
# Bước 417 : UP
# [8, 5, 0]
# [4, 1, 7]
# [2, 6, 3]
#
# Bước 418 : LEFT
# [8, 0, 5]
# [4, 1, 7]
# [2, 6, 3]
#
# Bước 419 : LEFT
# [0, 8, 5]
# [4, 1, 7]
# [2, 6, 3]
#
# Bước 420 : DOWN
# [4, 8, 5]
# [0, 1, 7]
# [2, 6, 3]
#
# Bước 421 : DOWN
# [4, 8, 5]
# [2, 1, 7]
# [0, 6, 3]
#
# Bước 422 : RIGHT
# [4, 8, 5]
# [2, 1, 7]
# [6, 0, 3]
#
# Bước 423 : UP
# [4, 8, 5]
# [2, 0, 7]
# [6, 1, 3]
#
# Bước 424 : LEFT
# [4, 8, 5]
# [0, 2, 7]
# [6, 1, 3]
#
# Bước 425 : DOWN
# [4, 8, 5]
# [6, 2, 7]
# [0, 1, 3]
#
# Bước 426 : RIGHT
# [4, 8, 5]
# [6, 2, 7]
# [1, 0, 3]
#
# Bước 427 : RIGHT
# [4, 8, 5]
# [6, 2, 7]
# [1, 3, 0]
#
# Bước 428 : UP
# [4, 8, 5]
# [6, 2, 0]
# [1, 3, 7]
#
# Bước 429 : UP
# [4, 8, 0]
# [6, 2, 5]
# [1, 3, 7]
#
# Bước 430 : LEFT
# [4, 0, 8]
# [6, 2, 5]
# [1, 3, 7]
#
# Bước 431 : LEFT
# [0, 4, 8]
# [6, 2, 5]
# [1, 3, 7]
#
# Bước 432 : DOWN
# [6, 4, 8]
# [0, 2, 5]
# [1, 3, 7]
#
# Bước 433 : RIGHT
# [6, 4, 8]
# [2, 0, 5]
# [1, 3, 7]
#
# Bước 434 : UP
# [6, 0, 8]
# [2, 4, 5]
# [1, 3, 7]
#
# Bước 435 : RIGHT
# [6, 8, 0]
# [2, 4, 5]
# [1, 3, 7]
#
# Bước 436 : DOWN
# [6, 8, 5]
# [2, 4, 0]
# [1, 3, 7]
#
# Bước 437 : LEFT
# [6, 8, 5]
# [2, 0, 4]
# [1, 3, 7]
#
# Bước 438 : LEFT
# [6, 8, 5]
# [0, 2, 4]
# [1, 3, 7]
#
# Bước 439 : UP
# [0, 8, 5]
# [6, 2, 4]
# [1, 3, 7]
#
# Bước 440 : RIGHT
# [8, 0, 5]
# [6, 2, 4]
# [1, 3, 7]
#
# Bước 441 : RIGHT
# [8, 5, 0]
# [6, 2, 4]
# [1, 3, 7]
#
# Bước 442 : DOWN
# [8, 5, 4]
# [6, 2, 0]
# [1, 3, 7]
#
# Bước 443 : DOWN
# [8, 5, 4]
# [6, 2, 7]
# [1, 3, 0]
#
# Bước 444 : LEFT
# [8, 5, 4]
# [6, 2, 7]
# [1, 0, 3]
#
# Bước 445 : LEFT
# [8, 5, 4]
# [6, 2, 7]
# [0, 1, 3]
#
# Bước 446 : UP
# [8, 5, 4]
# [0, 2, 7]
# [6, 1, 3]
#
# Bước 447 : RIGHT
# [8, 5, 4]
# [2, 0, 7]
# [6, 1, 3]
#
# Bước 448 : UP
# [8, 0, 4]
# [2, 5, 7]
# [6, 1, 3]
#
# Bước 449 : RIGHT
# [8, 4, 0]
# [2, 5, 7]
# [6, 1, 3]
#
# Bước 450 : DOWN
# [8, 4, 7]
# [2, 5, 0]
# [6, 1, 3]
#
# Bước 451 : LEFT
# [8, 4, 7]
# [2, 0, 5]
# [6, 1, 3]
#
# Bước 452 : LEFT
# [8, 4, 7]
# [0, 2, 5]
# [6, 1, 3]
#
# Bước 453 : UP
# [0, 4, 7]
# [8, 2, 5]
# [6, 1, 3]
#
# Bước 454 : RIGHT
# [4, 0, 7]
# [8, 2, 5]
# [6, 1, 3]
#
# Bước 455 : RIGHT
# [4, 7, 0]
# [8, 2, 5]
# [6, 1, 3]
#
# Bước 456 : DOWN
# [4, 7, 5]
# [8, 2, 0]
# [6, 1, 3]
#
# Bước 457 : LEFT
# [4, 7, 5]
# [8, 0, 2]
# [6, 1, 3]
#
# Bước 458 : DOWN
# [4, 7, 5]
# [8, 1, 2]
# [6, 0, 3]
#
# Bước 459 : LEFT
# [4, 7, 5]
# [8, 1, 2]
# [0, 6, 3]
#
# Bước 460 : UP
# [4, 7, 5]
# [0, 1, 2]
# [8, 6, 3]
#
# Bước 461 : RIGHT
# [4, 7, 5]
# [1, 0, 2]
# [8, 6, 3]
#
# Bước 462 : RIGHT
# [4, 7, 5]
# [1, 2, 0]
# [8, 6, 3]
#
# Bước 463 : UP
# [4, 7, 0]
# [1, 2, 5]
# [8, 6, 3]
#
# Bước 464 : LEFT
# [4, 0, 7]
# [1, 2, 5]
# [8, 6, 3]
#
# Bước 465 : LEFT
# [0, 4, 7]
# [1, 2, 5]
# [8, 6, 3]
#
# Bước 466 : DOWN
# [1, 4, 7]
# [0, 2, 5]
# [8, 6, 3]
#
# Bước 467 : RIGHT
# [1, 4, 7]
# [2, 0, 5]
# [8, 6, 3]
#
# Bước 468 : RIGHT
# [1, 4, 7]
# [2, 5, 0]
# [8, 6, 3]
#
# Bước 469 : UP
# [1, 4, 0]
# [2, 5, 7]
# [8, 6, 3]
#
# Bước 470 : LEFT
# [1, 0, 4]
# [2, 5, 7]
# [8, 6, 3]
#
# Bước 471 : DOWN
# [1, 5, 4]
# [2, 0, 7]
# [8, 6, 3]
#
# Bước 472 : DOWN
# [1, 5, 4]
# [2, 6, 7]
# [8, 0, 3]
#
# Bước 473 : RIGHT
# [1, 5, 4]
# [2, 6, 7]
# [8, 3, 0]
#
# Bước 474 : UP
# [1, 5, 4]
# [2, 6, 0]
# [8, 3, 7]
#
# Bước 475 : UP
# [1, 5, 0]
# [2, 6, 4]
# [8, 3, 7]
#
# Bước 476 : LEFT
# [1, 0, 5]
# [2, 6, 4]
# [8, 3, 7]
#
# Bước 477 : LEFT
# [0, 1, 5]
# [2, 6, 4]
# [8, 3, 7]
#
# Bước 478 : DOWN
# [2, 1, 5]
# [0, 6, 4]
# [8, 3, 7]
#
# Bước 479 : RIGHT
# [2, 1, 5]
# [6, 0, 4]
# [8, 3, 7]
#
# Bước 480 : RIGHT
# [2, 1, 5]
# [6, 4, 0]
# [8, 3, 7]
#
# Bước 481 : DOWN
# [2, 1, 5]
# [6, 4, 7]
# [8, 3, 0]
#
# Bước 482 : LEFT
# [2, 1, 5]
# [6, 4, 7]
# [8, 0, 3]
#
# Bước 483 : UP
# [2, 1, 5]
# [6, 0, 7]
# [8, 4, 3]
#
# Bước 484 : RIGHT
# [2, 1, 5]
# [6, 7, 0]
# [8, 4, 3]
#
# Bước 485 : DOWN
# [2, 1, 5]
# [6, 7, 3]
# [8, 4, 0]
#
# Bước 486 : LEFT
# [2, 1, 5]
# [6, 7, 3]
# [8, 0, 4]
#
# Bước 487 : LEFT
# [2, 1, 5]
# [6, 7, 3]
# [0, 8, 4]
#
# Bước 488 : UP
# [2, 1, 5]
# [0, 7, 3]
# [6, 8, 4]
#
# Bước 489 : RIGHT
# [2, 1, 5]
# [7, 0, 3]
# [6, 8, 4]
#
# Bước 490 : UP
# [2, 0, 5]
# [7, 1, 3]
# [6, 8, 4]
#
# Bước 491 : LEFT
# [0, 2, 5]
# [7, 1, 3]
# [6, 8, 4]
#
# Bước 492 : DOWN
# [7, 2, 5]
# [0, 1, 3]
# [6, 8, 4]
#
# Bước 493 : DOWN
# [7, 2, 5]
# [6, 1, 3]
# [0, 8, 4]
#
# Bước 494 : RIGHT
# [7, 2, 5]
# [6, 1, 3]
# [8, 0, 4]
#
# Bước 495 : RIGHT
# [7, 2, 5]
# [6, 1, 3]
# [8, 4, 0]
#
# Bước 496 : UP
# [7, 2, 5]
# [6, 1, 0]
# [8, 4, 3]
#
# Bước 497 : UP
# [7, 2, 0]
# [6, 1, 5]
# [8, 4, 3]
#
# Bước 498 : LEFT
# [7, 0, 2]
# [6, 1, 5]
# [8, 4, 3]
#
# Bước 499 : LEFT
# [0, 7, 2]
# [6, 1, 5]
# [8, 4, 3]
#
# Bước 500 : DOWN
# [6, 7, 2]
# [0, 1, 5]
# [8, 4, 3]
#
# Bước 501 : DOWN
# [6, 7, 2]
# [8, 1, 5]
# [0, 4, 3]
#
# Bước 502 : RIGHT
# [6, 7, 2]
# [8, 1, 5]
# [4, 0, 3]
#
# Bước 503 : UP
# [6, 7, 2]
# [8, 0, 5]
# [4, 1, 3]
#
# Bước 504 : RIGHT
# [6, 7, 2]
# [8, 5, 0]
# [4, 1, 3]
#
# Bước 505 : UP
# [6, 7, 0]
# [8, 5, 2]
# [4, 1, 3]
#
# Bước 506 : LEFT
# [6, 0, 7]
# [8, 5, 2]
# [4, 1, 3]
#
# Bước 507 : DOWN
# [6, 5, 7]
# [8, 0, 2]
# [4, 1, 3]
#
# Bước 508 : RIGHT
# [6, 5, 7]
# [8, 2, 0]
# [4, 1, 3]
#
# Bước 509 : DOWN
# [6, 5, 7]
# [8, 2, 3]
# [4, 1, 0]
#
# Bước 510 : LEFT
# [6, 5, 7]
# [8, 2, 3]
# [4, 0, 1]
#
# Bước 511 : UP
# [6, 5, 7]
# [8, 0, 3]
# [4, 2, 1]
#
# Bước 512 : LEFT
# [6, 5, 7]
# [0, 8, 3]
# [4, 2, 1]
#
# Bước 513 : UP
# [0, 5, 7]
# [6, 8, 3]
# [4, 2, 1]
#
# Bước 514 : RIGHT
# [5, 0, 7]
# [6, 8, 3]
# [4, 2, 1]
#
# Bước 515 : RIGHT
# [5, 7, 0]
# [6, 8, 3]
# [4, 2, 1]
#
# Bước 516 : DOWN
# [5, 7, 3]
# [6, 8, 0]
# [4, 2, 1]
#
# Bước 517 : LEFT
# [5, 7, 3]
# [6, 0, 8]
# [4, 2, 1]
#
# Bước 518 : UP
# [5, 0, 3]
# [6, 7, 8]
# [4, 2, 1]
#
# Bước 519 : RIGHT
# [5, 3, 0]
# [6, 7, 8]
# [4, 2, 1]
#
# Bước 520 : DOWN
# [5, 3, 8]
# [6, 7, 0]
# [4, 2, 1]
#
# Bước 521 : LEFT
# [5, 3, 8]
# [6, 0, 7]
# [4, 2, 1]
#
# Bước 522 : LEFT
# [5, 3, 8]
# [0, 6, 7]
# [4, 2, 1]
#
# Bước 523 : UP
# [0, 3, 8]
# [5, 6, 7]
# [4, 2, 1]
#
# Bước 524 : RIGHT
# [3, 0, 8]
# [5, 6, 7]
# [4, 2, 1]
#
# Bước 525 : DOWN
# [3, 6, 8]
# [5, 0, 7]
# [4, 2, 1]
#
# Bước 526 : DOWN
# [3, 6, 8]
# [5, 2, 7]
# [4, 0, 1]
#
# Bước 527 : LEFT
# [3, 6, 8]
# [5, 2, 7]
# [0, 4, 1]
#
# Bước 528 : UP
# [3, 6, 8]
# [0, 2, 7]
# [5, 4, 1]
#
# Bước 529 : RIGHT
# [3, 6, 8]
# [2, 0, 7]
# [5, 4, 1]
#
# Bước 530 : DOWN
# [3, 6, 8]
# [2, 4, 7]
# [5, 0, 1]
#
# Bước 531 : RIGHT
# [3, 6, 8]
# [2, 4, 7]
# [5, 1, 0]
#
# Bước 532 : UP
# [3, 6, 8]
# [2, 4, 0]
# [5, 1, 7]
#
# Bước 533 : UP
# [3, 6, 0]
# [2, 4, 8]
# [5, 1, 7]
#
# Bước 534 : LEFT
# [3, 0, 6]
# [2, 4, 8]
# [5, 1, 7]
#
# Bước 535 : LEFT
# [0, 3, 6]
# [2, 4, 8]
# [5, 1, 7]
#
# Bước 536 : DOWN
# [2, 3, 6]
# [0, 4, 8]
# [5, 1, 7]
#
# Bước 537 : DOWN
# [2, 3, 6]
# [5, 4, 8]
# [0, 1, 7]
#
# Bước 538 : RIGHT
# [2, 3, 6]
# [5, 4, 8]
# [1, 0, 7]
#
# Bước 539 : RIGHT
# [2, 3, 6]
# [5, 4, 8]
# [1, 7, 0]
#
# Bước 540 : UP
# [2, 3, 6]
# [5, 4, 0]
# [1, 7, 8]
#
# Bước 541 : LEFT
# [2, 3, 6]
# [5, 0, 4]
# [1, 7, 8]
#
# Bước 542 : DOWN
# [2, 3, 6]
# [5, 7, 4]
# [1, 0, 8]
#
# Bước 543 : LEFT
# [2, 3, 6]
# [5, 7, 4]
# [0, 1, 8]
#
# Bước 544 : UP
# [2, 3, 6]
# [0, 7, 4]
# [5, 1, 8]
#
# Bước 545 : RIGHT
# [2, 3, 6]
# [7, 0, 4]
# [5, 1, 8]
#
# Bước 546 : DOWN
# [2, 3, 6]
# [7, 1, 4]
# [5, 0, 8]
#
# Bước 547 : LEFT
# [2, 3, 6]
# [7, 1, 4]
# [0, 5, 8]
#
# Bước 548 : UP
# [2, 3, 6]
# [0, 1, 4]
# [7, 5, 8]
#
# Bước 549 : UP
# [0, 3, 6]
# [2, 1, 4]
# [7, 5, 8]
#
# Bước 550 : RIGHT
# [3, 0, 6]
# [2, 1, 4]
# [7, 5, 8]
#
# Bước 551 : RIGHT
# [3, 6, 0]
# [2, 1, 4]
# [7, 5, 8]
#
# Bước 552 : DOWN
# [3, 6, 4]
# [2, 1, 0]
# [7, 5, 8]
#
# Bước 553 : DOWN
# [3, 6, 4]
# [2, 1, 8]
# [7, 5, 0]
#
# Bước 554 : LEFT
# [3, 6, 4]
# [2, 1, 8]
# [7, 0, 5]
#
# Bước 555 : LEFT
# [3, 6, 4]
# [2, 1, 8]
# [0, 7, 5]
#
# Bước 556 : UP
# [3, 6, 4]
# [0, 1, 8]
# [2, 7, 5]
#
# Bước 557 : RIGHT
# [3, 6, 4]
# [1, 0, 8]
# [2, 7, 5]
#
# Bước 558 : DOWN
# [3, 6, 4]
# [1, 7, 8]
# [2, 0, 5]
#
# Bước 559 : LEFT
# [3, 6, 4]
# [1, 7, 8]
# [0, 2, 5]
#
# Bước 560 : UP
# [3, 6, 4]
# [0, 7, 8]
# [1, 2, 5]
#
# Bước 561 : RIGHT
# [3, 6, 4]
# [7, 0, 8]
# [1, 2, 5]
#
# Bước 562 : UP
# [3, 0, 4]
# [7, 6, 8]
# [1, 2, 5]
#
# Bước 563 : RIGHT
# [3, 4, 0]
# [7, 6, 8]
# [1, 2, 5]
#
# Bước 564 : DOWN
# [3, 4, 8]
# [7, 6, 0]
# [1, 2, 5]
#
# Bước 565 : LEFT
# [3, 4, 8]
# [7, 0, 6]
# [1, 2, 5]
#
# Bước 566 : DOWN
# [3, 4, 8]
# [7, 2, 6]
# [1, 0, 5]
#
# Bước 567 : LEFT
# [3, 4, 8]
# [7, 2, 6]
# [0, 1, 5]
#
# Bước 568 : UP
# [3, 4, 8]
# [0, 2, 6]
# [7, 1, 5]
#
# Bước 569 : RIGHT
# [3, 4, 8]
# [2, 0, 6]
# [7, 1, 5]
#
# Bước 570 : UP
# [3, 0, 8]
# [2, 4, 6]
# [7, 1, 5]
#
# Bước 571 : LEFT
# [0, 3, 8]
# [2, 4, 6]
# [7, 1, 5]
#
# Bước 572 : DOWN
# [2, 3, 8]
# [0, 4, 6]
# [7, 1, 5]
#
# Bước 573 : DOWN
# [2, 3, 8]
# [7, 4, 6]
# [0, 1, 5]
#
# Bước 574 : RIGHT
# [2, 3, 8]
# [7, 4, 6]
# [1, 0, 5]
#
# Bước 575 : UP
# [2, 3, 8]
# [7, 0, 6]
# [1, 4, 5]
#
# Bước 576 : RIGHT
# [2, 3, 8]
# [7, 6, 0]
# [1, 4, 5]
#
# Bước 577 : DOWN
# [2, 3, 8]
# [7, 6, 5]
# [1, 4, 0]
#
# Bước 578 : LEFT
# [2, 3, 8]
# [7, 6, 5]
# [1, 0, 4]
#
# Bước 579 : UP
# [2, 3, 8]
# [7, 0, 5]
# [1, 6, 4]
#
# Bước 580 : RIGHT
# [2, 3, 8]
# [7, 5, 0]
# [1, 6, 4]
#
# Bước 581 : DOWN
# [2, 3, 8]
# [7, 5, 4]
# [1, 6, 0]
#
# Bước 582 : LEFT
# [2, 3, 8]
# [7, 5, 4]
# [1, 0, 6]
#
# Bước 583 : LEFT
# [2, 3, 8]
# [7, 5, 4]
# [0, 1, 6]
#
# Bước 584 : UP
# [2, 3, 8]
# [0, 5, 4]
# [7, 1, 6]
#
# Bước 585 : RIGHT
# [2, 3, 8]
# [5, 0, 4]
# [7, 1, 6]
#
# Bước 586 : UP
# [2, 0, 8]
# [5, 3, 4]
# [7, 1, 6]
#
# Bước 587 : LEFT
# [0, 2, 8]
# [5, 3, 4]
# [7, 1, 6]
#
# Bước 588 : DOWN
# [5, 2, 8]
# [0, 3, 4]
# [7, 1, 6]
#
# Bước 589 : DOWN
# [5, 2, 8]
# [7, 3, 4]
# [0, 1, 6]
#
# Bước 590 : RIGHT
# [5, 2, 8]
# [7, 3, 4]
# [1, 0, 6]
#
# Bước 591 : RIGHT
# [5, 2, 8]
# [7, 3, 4]
# [1, 6, 0]
#
# Bước 592 : UP
# [5, 2, 8]
# [7, 3, 0]
# [1, 6, 4]
#
# Bước 593 : LEFT
# [5, 2, 8]
# [7, 0, 3]
# [1, 6, 4]
#
# Bước 594 : UP
# [5, 0, 8]
# [7, 2, 3]
# [1, 6, 4]
#
# Bước 595 : LEFT
# [0, 5, 8]
# [7, 2, 3]
# [1, 6, 4]
#
# Bước 596 : DOWN
# [7, 5, 8]
# [0, 2, 3]
# [1, 6, 4]
#
# Bước 597 : DOWN
# [7, 5, 8]
# [1, 2, 3]
# [0, 6, 4]
#
# Bước 598 : RIGHT
# [7, 5, 8]
# [1, 2, 3]
# [6, 0, 4]
#
# Bước 599 : UP
# [7, 5, 8]
# [1, 0, 3]
# [6, 2, 4]
#
# Bước 600 : UP
# [7, 0, 8]
# [1, 5, 3]
# [6, 2, 4]
#
# Bước 601 : LEFT
# [0, 7, 8]
# [1, 5, 3]
# [6, 2, 4]
#
# Bước 602 : DOWN
# [1, 7, 8]
# [0, 5, 3]
# [6, 2, 4]
#
# Bước 603 : DOWN
# [1, 7, 8]
# [6, 5, 3]
# [0, 2, 4]
#
# Bước 604 : RIGHT
# [1, 7, 8]
# [6, 5, 3]
# [2, 0, 4]
#
# Bước 605 : UP
# [1, 7, 8]
# [6, 0, 3]
# [2, 5, 4]
#
# Bước 606 : RIGHT
# [1, 7, 8]
# [6, 3, 0]
# [2, 5, 4]
#
# Bước 607 : DOWN
# [1, 7, 8]
# [6, 3, 4]
# [2, 5, 0]
#
# Bước 608 : LEFT
# [1, 7, 8]
# [6, 3, 4]
# [2, 0, 5]
#
# Bước 609 : UP
# [1, 7, 8]
# [6, 0, 4]
# [2, 3, 5]
#
# Bước 610 : RIGHT
# [1, 7, 8]
# [6, 4, 0]
# [2, 3, 5]
#
# Bước 611 : UP
# [1, 7, 0]
# [6, 4, 8]
# [2, 3, 5]
#
# Bước 612 : LEFT
# [1, 0, 7]
# [6, 4, 8]
# [2, 3, 5]
#
# Bước 613 : DOWN
# [1, 4, 7]
# [6, 0, 8]
# [2, 3, 5]
#
# Bước 614 : RIGHT
# [1, 4, 7]
# [6, 8, 0]
# [2, 3, 5]
#
# Bước 615 : UP
# [1, 4, 0]
# [6, 8, 7]
# [2, 3, 5]
#
# Bước 616 : LEFT
# [1, 0, 4]
# [6, 8, 7]
# [2, 3, 5]
#
# Bước 617 : LEFT
# [0, 1, 4]
# [6, 8, 7]
# [2, 3, 5]
#
# Bước 618 : DOWN
# [6, 1, 4]
# [0, 8, 7]
# [2, 3, 5]
#
# Bước 619 : RIGHT
# [6, 1, 4]
# [8, 0, 7]
# [2, 3, 5]
#
# Bước 620 : RIGHT
# [6, 1, 4]
# [8, 7, 0]
# [2, 3, 5]
#
# Bước 621 : DOWN
# [6, 1, 4]
# [8, 7, 5]
# [2, 3, 0]
#
# Bước 622 : LEFT
# [6, 1, 4]
# [8, 7, 5]
# [2, 0, 3]
#
# Bước 623 : UP
# [6, 1, 4]
# [8, 0, 5]
# [2, 7, 3]
#
# Bước 624 : UP
# [6, 0, 4]
# [8, 1, 5]
# [2, 7, 3]
#
# Bước 625 : RIGHT
# [6, 4, 0]
# [8, 1, 5]
# [2, 7, 3]
#
# Bước 626 : DOWN
# [6, 4, 5]
# [8, 1, 0]
# [2, 7, 3]
#
# Bước 627 : LEFT
# [6, 4, 5]
# [8, 0, 1]
# [2, 7, 3]
#
# Bước 628 : DOWN
# [6, 4, 5]
# [8, 7, 1]
# [2, 0, 3]
#
# Bước 629 : RIGHT
# [6, 4, 5]
# [8, 7, 1]
# [2, 3, 0]
#
# Bước 630 : UP
# [6, 4, 5]
# [8, 7, 0]
# [2, 3, 1]
#
# Bước 631 : UP
# [6, 4, 0]
# [8, 7, 5]
# [2, 3, 1]
#
# Bước 632 : LEFT
# [6, 0, 4]
# [8, 7, 5]
# [2, 3, 1]
#
# Bước 633 : DOWN
# [6, 7, 4]
# [8, 0, 5]
# [2, 3, 1]
#
# Bước 634 : DOWN
# [6, 7, 4]
# [8, 3, 5]
# [2, 0, 1]
#
# Bước 635 : LEFT
# [6, 7, 4]
# [8, 3, 5]
# [0, 2, 1]
#
# Bước 636 : UP
# [6, 7, 4]
# [0, 3, 5]
# [8, 2, 1]
#
# Bước 637 : RIGHT
# [6, 7, 4]
# [3, 0, 5]
# [8, 2, 1]
#
# Bước 638 : RIGHT
# [6, 7, 4]
# [3, 5, 0]
# [8, 2, 1]
#
# Bước 639 : UP
# [6, 7, 0]
# [3, 5, 4]
# [8, 2, 1]
#
# Bước 640 : LEFT
# [6, 0, 7]
# [3, 5, 4]
# [8, 2, 1]
#
# Bước 641 : DOWN
# [6, 5, 7]
# [3, 0, 4]
# [8, 2, 1]
#
# Bước 642 : DOWN
# [6, 5, 7]
# [3, 2, 4]
# [8, 0, 1]
#
# Bước 643 : RIGHT
# [6, 5, 7]
# [3, 2, 4]
# [8, 1, 0]
#
# Bước 644 : UP
# [6, 5, 7]
# [3, 2, 0]
# [8, 1, 4]
#
# Bước 645 : LEFT
# [6, 5, 7]
# [3, 0, 2]
# [8, 1, 4]
#
# Bước 646 : DOWN
# [6, 5, 7]
# [3, 1, 2]
# [8, 0, 4]
#
# Bước 647 : LEFT
# [6, 5, 7]
# [3, 1, 2]
# [0, 8, 4]
#
# Bước 648 : UP
# [6, 5, 7]
# [0, 1, 2]
# [3, 8, 4]
#
# Bước 649 : UP
# [0, 5, 7]
# [6, 1, 2]
# [3, 8, 4]
#
# Bước 650 : RIGHT
# [5, 0, 7]
# [6, 1, 2]
# [3, 8, 4]
#
# Bước 651 : RIGHT
# [5, 7, 0]
# [6, 1, 2]
# [3, 8, 4]
#
# Bước 652 : DOWN
# [5, 7, 2]
# [6, 1, 0]
# [3, 8, 4]
#
# Bước 653 : DOWN
# [5, 7, 2]
# [6, 1, 4]
# [3, 8, 0]
#
# Bước 654 : LEFT
# [5, 7, 2]
# [6, 1, 4]
# [3, 0, 8]
#
# Bước 655 : LEFT
# [5, 7, 2]
# [6, 1, 4]
# [0, 3, 8]
#
# Bước 656 : UP
# [5, 7, 2]
# [0, 1, 4]
# [6, 3, 8]
#
# Bước 657 : RIGHT
# [5, 7, 2]
# [1, 0, 4]
# [6, 3, 8]
#
# Bước 658 : UP
# [5, 0, 2]
# [1, 7, 4]
# [6, 3, 8]
#
# Bước 659 : LEFT
# [0, 5, 2]
# [1, 7, 4]
# [6, 3, 8]
#
# Bước 660 : DOWN
# [1, 5, 2]
# [0, 7, 4]
# [6, 3, 8]
#
# Bước 661 : RIGHT
# [1, 5, 2]
# [7, 0, 4]
# [6, 3, 8]
#
# Bước 662 : DOWN
# [1, 5, 2]
# [7, 3, 4]
# [6, 0, 8]
#
# Bước 663 : LEFT
# [1, 5, 2]
# [7, 3, 4]
# [0, 6, 8]
#
# Bước 664 : UP
# [1, 5, 2]
# [0, 3, 4]
# [7, 6, 8]
#
# Bước 665 : UP
# [0, 5, 2]
# [1, 3, 4]
# [7, 6, 8]
#
# Bước 666 : RIGHT
# [5, 0, 2]
# [1, 3, 4]
# [7, 6, 8]
#
# Bước 667 : DOWN
# [5, 3, 2]
# [1, 0, 4]
# [7, 6, 8]
#
# Bước 668 : DOWN
# [5, 3, 2]
# [1, 6, 4]
# [7, 0, 8]
#
# Bước 669 : RIGHT
# [5, 3, 2]
# [1, 6, 4]
# [7, 8, 0]
#
# Bước 670 : UP
# [5, 3, 2]
# [1, 6, 0]
# [7, 8, 4]
#
# Bước 671 : LEFT
# [5, 3, 2]
# [1, 0, 6]
# [7, 8, 4]
#
# Bước 672 : DOWN
# [5, 3, 2]
# [1, 8, 6]
# [7, 0, 4]
#
# Bước 673 : RIGHT
# [5, 3, 2]
# [1, 8, 6]
# [7, 4, 0]
#
# Bước 674 : UP
# [5, 3, 2]
# [1, 8, 0]
# [7, 4, 6]
#
# Bước 675 : LEFT
# [5, 3, 2]
# [1, 0, 8]
# [7, 4, 6]
#
# Bước 676 : UP
# [5, 0, 2]
# [1, 3, 8]
# [7, 4, 6]
#
# Bước 677 : LEFT
# [0, 5, 2]
# [1, 3, 8]
# [7, 4, 6]
#
# Bước 678 : DOWN
# [1, 5, 2]
# [0, 3, 8]
# [7, 4, 6]
#
# Bước 679 : RIGHT
# [1, 5, 2]
# [3, 0, 8]
# [7, 4, 6]
#
# Bước 680 : RIGHT
# [1, 5, 2]
# [3, 8, 0]
# [7, 4, 6]
#
# Bước 681 : UP
# [1, 5, 0]
# [3, 8, 2]
# [7, 4, 6]
#
# Bước 682 : LEFT
# [1, 0, 5]
# [3, 8, 2]
# [7, 4, 6]
#
# Bước 683 : LEFT
# [0, 1, 5]
# [3, 8, 2]
# [7, 4, 6]
#
# Bước 684 : DOWN
# [3, 1, 5]
# [0, 8, 2]
# [7, 4, 6]
#
# Bước 685 : RIGHT
# [3, 1, 5]
# [8, 0, 2]
# [7, 4, 6]
#
# Bước 686 : UP
# [3, 0, 5]
# [8, 1, 2]
# [7, 4, 6]
#
# Bước 687 : RIGHT
# [3, 5, 0]
# [8, 1, 2]
# [7, 4, 6]
#
# Bước 688 : DOWN
# [3, 5, 2]
# [8, 1, 0]
# [7, 4, 6]
#
# Bước 689 : DOWN
# [3, 5, 2]
# [8, 1, 6]
# [7, 4, 0]
#
# Bước 690 : LEFT
# [3, 5, 2]
# [8, 1, 6]
# [7, 0, 4]
#
# Bước 691 : LEFT
# [3, 5, 2]
# [8, 1, 6]
# [0, 7, 4]
#
# Bước 692 : UP
# [3, 5, 2]
# [0, 1, 6]
# [8, 7, 4]
#
# Bước 693 : RIGHT
# [3, 5, 2]
# [1, 0, 6]
# [8, 7, 4]
#
# Bước 694 : DOWN
# [3, 5, 2]
# [1, 7, 6]
# [8, 0, 4]
#
# Bước 695 : LEFT
# [3, 5, 2]
# [1, 7, 6]
# [0, 8, 4]
#
# Bước 696 : UP
# [3, 5, 2]
# [0, 7, 6]
# [1, 8, 4]
#
# Bước 697 : UP
# [0, 5, 2]
# [3, 7, 6]
# [1, 8, 4]
#
# Bước 698 : RIGHT
# [5, 0, 2]
# [3, 7, 6]
# [1, 8, 4]
#
# Bước 699 : DOWN
# [5, 7, 2]
# [3, 0, 6]
# [1, 8, 4]
#
# Bước 700 : DOWN
# [5, 7, 2]
# [3, 8, 6]
# [1, 0, 4]
#
# Bước 701 : RIGHT
# [5, 7, 2]
# [3, 8, 6]
# [1, 4, 0]
#
# Bước 702 : UP
# [5, 7, 2]
# [3, 8, 0]
# [1, 4, 6]
#
# Bước 703 : UP
# [5, 7, 0]
# [3, 8, 2]
# [1, 4, 6]
#
# Bước 704 : LEFT
# [5, 0, 7]
# [3, 8, 2]
# [1, 4, 6]
#
# Bước 705 : LEFT
# [0, 5, 7]
# [3, 8, 2]
# [1, 4, 6]
#
# Bước 706 : DOWN
# [3, 5, 7]
# [0, 8, 2]
# [1, 4, 6]
#
# Bước 707 : DOWN
# [3, 5, 7]
# [1, 8, 2]
# [0, 4, 6]
#
# Bước 708 : RIGHT
# [3, 5, 7]
# [1, 8, 2]
# [4, 0, 6]
#
# Bước 709 : UP
# [3, 5, 7]
# [1, 0, 2]
# [4, 8, 6]
#
# Bước 710 : LEFT
# [3, 5, 7]
# [0, 1, 2]
# [4, 8, 6]
#
# Bước 711 : UP
# [0, 5, 7]
# [3, 1, 2]
# [4, 8, 6]
#
# Bước 712 : RIGHT
# [5, 0, 7]
# [3, 1, 2]
# [4, 8, 6]
#
# Bước 713 : RIGHT
# [5, 7, 0]
# [3, 1, 2]
# [4, 8, 6]
#
# Bước 714 : DOWN
# [5, 7, 2]
# [3, 1, 0]
# [4, 8, 6]
#
# Bước 715 : DOWN
# [5, 7, 2]
# [3, 1, 6]
# [4, 8, 0]
#
# Bước 716 : LEFT
# [5, 7, 2]
# [3, 1, 6]
# [4, 0, 8]
#
# Bước 717 : UP
# [5, 7, 2]
# [3, 0, 6]
# [4, 1, 8]
#
# Bước 718 : RIGHT
# [5, 7, 2]
# [3, 6, 0]
# [4, 1, 8]
#
# Bước 719 : UP
# [5, 7, 0]
# [3, 6, 2]
# [4, 1, 8]
#
# Bước 720 : LEFT
# [5, 0, 7]
# [3, 6, 2]
# [4, 1, 8]
#
# Bước 721 : LEFT
# [0, 5, 7]
# [3, 6, 2]
# [4, 1, 8]
#
# Bước 722 : DOWN
# [3, 5, 7]
# [0, 6, 2]
# [4, 1, 8]
#
# Bước 723 : DOWN
# [3, 5, 7]
# [4, 6, 2]
# [0, 1, 8]
#
# Bước 724 : RIGHT
# [3, 5, 7]
# [4, 6, 2]
# [1, 0, 8]
#
# Bước 725 : RIGHT
# [3, 5, 7]
# [4, 6, 2]
# [1, 8, 0]
#
# Bước 726 : UP
# [3, 5, 7]
# [4, 6, 0]
# [1, 8, 2]
#
# Bước 727 : LEFT
# [3, 5, 7]
# [4, 0, 6]
# [1, 8, 2]
#
# Bước 728 : DOWN
# [3, 5, 7]
# [4, 8, 6]
# [1, 0, 2]
#
# Bước 729 : LEFT
# [3, 5, 7]
# [4, 8, 6]
# [0, 1, 2]
#
# Bước 730 : UP
# [3, 5, 7]
# [0, 8, 6]
# [4, 1, 2]
#
# Bước 731 : RIGHT
# [3, 5, 7]
# [8, 0, 6]
# [4, 1, 2]
#
# Bước 732 : UP
# [3, 0, 7]
# [8, 5, 6]
# [4, 1, 2]
#
# Bước 733 : LEFT
# [0, 3, 7]
# [8, 5, 6]
# [4, 1, 2]
#
# Bước 734 : DOWN
# [8, 3, 7]
# [0, 5, 6]
# [4, 1, 2]
#
# Bước 735 : RIGHT
# [8, 3, 7]
# [5, 0, 6]
# [4, 1, 2]
#
# Bước 736 : RIGHT
# [8, 3, 7]
# [5, 6, 0]
# [4, 1, 2]
#
# Bước 737 : UP
# [8, 3, 0]
# [5, 6, 7]
# [4, 1, 2]
#
# Bước 738 : LEFT
# [8, 0, 3]
# [5, 6, 7]
# [4, 1, 2]
#
# Bước 739 : DOWN
# [8, 6, 3]
# [5, 0, 7]
# [4, 1, 2]
#
# Bước 740 : LEFT
# [8, 6, 3]
# [0, 5, 7]
# [4, 1, 2]
#
# Bước 741 : DOWN
# [8, 6, 3]
# [4, 5, 7]
# [0, 1, 2]
#
# Bước 742 : RIGHT
# [8, 6, 3]
# [4, 5, 7]
# [1, 0, 2]
#
# Bước 743 : RIGHT
# [8, 6, 3]
# [4, 5, 7]
# [1, 2, 0]
#
# Bước 744 : UP
# [8, 6, 3]
# [4, 5, 0]
# [1, 2, 7]
#
# Bước 745 : LEFT
# [8, 6, 3]
# [4, 0, 5]
# [1, 2, 7]
#
# Bước 746 : UP
# [8, 0, 3]
# [4, 6, 5]
# [1, 2, 7]
#
# Bước 747 : RIGHT
# [8, 3, 0]
# [4, 6, 5]
# [1, 2, 7]
#
# Bước 748 : DOWN
# [8, 3, 5]
# [4, 6, 0]
# [1, 2, 7]
#
# Bước 749 : LEFT
# [8, 3, 5]
# [4, 0, 6]
# [1, 2, 7]
#
# Bước 750 : LEFT
# [8, 3, 5]
# [0, 4, 6]
# [1, 2, 7]
#
# Bước 751 : DOWN
# [8, 3, 5]
# [1, 4, 6]
# [0, 2, 7]
#
# Bước 752 : RIGHT
# [8, 3, 5]
# [1, 4, 6]
# [2, 0, 7]
#
# Bước 753 : RIGHT
# [8, 3, 5]
# [1, 4, 6]
# [2, 7, 0]
#
# Bước 754 : UP
# [8, 3, 5]
# [1, 4, 0]
# [2, 7, 6]
#
# Bước 755 : LEFT
# [8, 3, 5]
# [1, 0, 4]
# [2, 7, 6]
#
# Bước 756 : UP
# [8, 0, 5]
# [1, 3, 4]
# [2, 7, 6]
#
# Bước 757 : RIGHT
# [8, 5, 0]
# [1, 3, 4]
# [2, 7, 6]
#
# Bước 758 : DOWN
# [8, 5, 4]
# [1, 3, 0]
# [2, 7, 6]
#
# Bước 759 : LEFT
# [8, 5, 4]
# [1, 0, 3]
# [2, 7, 6]
#
# Bước 760 : DOWN
# [8, 5, 4]
# [1, 7, 3]
# [2, 0, 6]
#
# Bước 761 : RIGHT
# [8, 5, 4]
# [1, 7, 3]
# [2, 6, 0]
#
# Bước 762 : UP
# [8, 5, 4]
# [1, 7, 0]
# [2, 6, 3]
#
# Bước 763 : UP
# [8, 5, 0]
# [1, 7, 4]
# [2, 6, 3]
#
# Bước 764 : LEFT
# [8, 0, 5]
# [1, 7, 4]
# [2, 6, 3]
#
# Bước 765 : DOWN
# [8, 7, 5]
# [1, 0, 4]
# [2, 6, 3]
#
# Bước 766 : LEFT
# [8, 7, 5]
# [0, 1, 4]
# [2, 6, 3]
#
# Bước 767 : UP
# [0, 7, 5]
# [8, 1, 4]
# [2, 6, 3]
#
# Bước 768 : RIGHT
# [7, 0, 5]
# [8, 1, 4]
# [2, 6, 3]
#
# Bước 769 : DOWN
# [7, 1, 5]
# [8, 0, 4]
# [2, 6, 3]
#
# Bước 770 : RIGHT
# [7, 1, 5]
# [8, 4, 0]
# [2, 6, 3]
#
# Bước 771 : DOWN
# [7, 1, 5]
# [8, 4, 3]
# [2, 6, 0]
#
# Bước 772 : LEFT
# [7, 1, 5]
# [8, 4, 3]
# [2, 0, 6]
#
# Bước 773 : UP
# [7, 1, 5]
# [8, 0, 3]
# [2, 4, 6]
#
# Bước 774 : UP
# [7, 0, 5]
# [8, 1, 3]
# [2, 4, 6]
#
# Bước 775 : RIGHT
# [7, 5, 0]
# [8, 1, 3]
# [2, 4, 6]
#
# Bước 776 : DOWN
# [7, 5, 3]
# [8, 1, 0]
# [2, 4, 6]
#
# Bước 777 : DOWN
# [7, 5, 3]
# [8, 1, 6]
# [2, 4, 0]
#
# Bước 778 : LEFT
# [7, 5, 3]
# [8, 1, 6]
# [2, 0, 4]
#
# Bước 779 : UP
# [7, 5, 3]
# [8, 0, 6]
# [2, 1, 4]
#
# Bước 780 : LEFT
# [7, 5, 3]
# [0, 8, 6]
# [2, 1, 4]
#
# Bước 781 : UP
# [0, 5, 3]
# [7, 8, 6]
# [2, 1, 4]
#
# Bước 782 : RIGHT
# [5, 0, 3]
# [7, 8, 6]
# [2, 1, 4]
#
# Bước 783 : RIGHT
# [5, 3, 0]
# [7, 8, 6]
# [2, 1, 4]
#
# Bước 784 : DOWN
# [5, 3, 6]
# [7, 8, 0]
# [2, 1, 4]
#
# Bước 785 : DOWN
# [5, 3, 6]
# [7, 8, 4]
# [2, 1, 0]
#
# Bước 786 : LEFT
# [5, 3, 6]
# [7, 8, 4]
# [2, 0, 1]
#
# Bước 787 : UP
# [5, 3, 6]
# [7, 0, 4]
# [2, 8, 1]
#
# Bước 788 : LEFT
# [5, 3, 6]
# [0, 7, 4]
# [2, 8, 1]
#
# Bước 789 : UP
# [0, 3, 6]
# [5, 7, 4]
# [2, 8, 1]
#
# Bước 790 : RIGHT
# [3, 0, 6]
# [5, 7, 4]
# [2, 8, 1]
#
# Bước 791 : DOWN
# [3, 7, 6]
# [5, 0, 4]
# [2, 8, 1]
#
# Bước 792 : DOWN
# [3, 7, 6]
# [5, 8, 4]
# [2, 0, 1]
#
# Bước 793 : RIGHT
# [3, 7, 6]
# [5, 8, 4]
# [2, 1, 0]
#
# Bước 794 : UP
# [3, 7, 6]
# [5, 8, 0]
# [2, 1, 4]
#
# Bước 795 : UP
# [3, 7, 0]
# [5, 8, 6]
# [2, 1, 4]
#
# Bước 796 : LEFT
# [3, 0, 7]
# [5, 8, 6]
# [2, 1, 4]
#
# Bước 797 : LEFT
# [0, 3, 7]
# [5, 8, 6]
# [2, 1, 4]
#
# Bước 798 : DOWN
# [5, 3, 7]
# [0, 8, 6]
# [2, 1, 4]
#
# Bước 799 : RIGHT
# [5, 3, 7]
# [8, 0, 6]
# [2, 1, 4]
#
# Bước 800 : UP
# [5, 0, 7]
# [8, 3, 6]
# [2, 1, 4]
#
# Bước 801 : RIGHT
# [5, 7, 0]
# [8, 3, 6]
# [2, 1, 4]
#
# Bước 802 : DOWN
# [5, 7, 6]
# [8, 3, 0]
# [2, 1, 4]
#
# Bước 803 : DOWN
# [5, 7, 6]
# [8, 3, 4]
# [2, 1, 0]
#
# Bước 804 : LEFT
# [5, 7, 6]
# [8, 3, 4]
# [2, 0, 1]
#
# Bước 805 : LEFT
# [5, 7, 6]
# [8, 3, 4]
# [0, 2, 1]
#
# Bước 806 : UP
# [5, 7, 6]
# [0, 3, 4]
# [8, 2, 1]
#
# Bước 807 : UP
# [0, 7, 6]
# [5, 3, 4]
# [8, 2, 1]
#
# Bước 808 : RIGHT
# [7, 0, 6]
# [5, 3, 4]
# [8, 2, 1]
#
# Bước 809 : DOWN
# [7, 3, 6]
# [5, 0, 4]
# [8, 2, 1]
#
# Bước 810 : RIGHT
# [7, 3, 6]
# [5, 4, 0]
# [8, 2, 1]
#
# Bước 811 : UP
# [7, 3, 0]
# [5, 4, 6]
# [8, 2, 1]
#
# Bước 812 : LEFT
# [7, 0, 3]
# [5, 4, 6]
# [8, 2, 1]
#
# Bước 813 : DOWN
# [7, 4, 3]
# [5, 0, 6]
# [8, 2, 1]
#
# Bước 814 : DOWN
# [7, 4, 3]
# [5, 2, 6]
# [8, 0, 1]
#
# Bước 815 : LEFT
# [7, 4, 3]
# [5, 2, 6]
# [0, 8, 1]
#
# Bước 816 : UP
# [7, 4, 3]
# [0, 2, 6]
# [5, 8, 1]
#
# Bước 817 : RIGHT
# [7, 4, 3]
# [2, 0, 6]
# [5, 8, 1]
#
# Bước 818 : UP
# [7, 0, 3]
# [2, 4, 6]
# [5, 8, 1]
#
# Bước 819 : RIGHT
# [7, 3, 0]
# [2, 4, 6]
# [5, 8, 1]
#
# Bước 820 : DOWN
# [7, 3, 6]
# [2, 4, 0]
# [5, 8, 1]
#
# Bước 821 : DOWN
# [7, 3, 6]
# [2, 4, 1]
# [5, 8, 0]
#
# Bước 822 : LEFT
# [7, 3, 6]
# [2, 4, 1]
# [5, 0, 8]
#
# Bước 823 : UP
# [7, 3, 6]
# [2, 0, 1]
# [5, 4, 8]
#
# Bước 824 : RIGHT
# [7, 3, 6]
# [2, 1, 0]
# [5, 4, 8]
#
# Bước 825 : DOWN
# [7, 3, 6]
# [2, 1, 8]
# [5, 4, 0]
#
# Bước 826 : LEFT
# [7, 3, 6]
# [2, 1, 8]
# [5, 0, 4]
#
# Bước 827 : UP
# [7, 3, 6]
# [2, 0, 8]
# [5, 1, 4]
#
# Bước 828 : LEFT
# [7, 3, 6]
# [0, 2, 8]
# [5, 1, 4]
#
# Bước 829 : DOWN
# [7, 3, 6]
# [5, 2, 8]
# [0, 1, 4]
#
# Bước 830 : RIGHT
# [7, 3, 6]
# [5, 2, 8]
# [1, 0, 4]
#
# Bước 831 : UP
# [7, 3, 6]
# [5, 0, 8]
# [1, 2, 4]
#
# Bước 832 : LEFT
# [7, 3, 6]
# [0, 5, 8]
# [1, 2, 4]
#
# Bước 833 : UP
# [0, 3, 6]
# [7, 5, 8]
# [1, 2, 4]
#
# Bước 834 : RIGHT
# [3, 0, 6]
# [7, 5, 8]
# [1, 2, 4]
#
# Bước 835 : RIGHT
# [3, 6, 0]
# [7, 5, 8]
# [1, 2, 4]
#
# Bước 836 : DOWN
# [3, 6, 8]
# [7, 5, 0]
# [1, 2, 4]
#
# Bước 837 : DOWN
# [3, 6, 8]
# [7, 5, 4]
# [1, 2, 0]
#
# Bước 838 : LEFT
# [3, 6, 8]
# [7, 5, 4]
# [1, 0, 2]
#
# Bước 839 : UP
# [3, 6, 8]
# [7, 0, 4]
# [1, 5, 2]
#
# Bước 840 : RIGHT
# [3, 6, 8]
# [7, 4, 0]
# [1, 5, 2]
#
# Bước 841 : DOWN
# [3, 6, 8]
# [7, 4, 2]
# [1, 5, 0]
#
# Bước 842 : LEFT
# [3, 6, 8]
# [7, 4, 2]
# [1, 0, 5]
#
# Bước 843 : LEFT
# [3, 6, 8]
# [7, 4, 2]
# [0, 1, 5]
#
# Bước 844 : UP
# [3, 6, 8]
# [0, 4, 2]
# [7, 1, 5]
#
# Bước 845 : RIGHT
# [3, 6, 8]
# [4, 0, 2]
# [7, 1, 5]
#
# Bước 846 : DOWN
# [3, 6, 8]
# [4, 1, 2]
# [7, 0, 5]
#
# Bước 847 : LEFT
# [3, 6, 8]
# [4, 1, 2]
# [0, 7, 5]
#
# Bước 848 : UP
# [3, 6, 8]
# [0, 1, 2]
# [4, 7, 5]
#
# Bước 849 : UP
# [0, 6, 8]
# [3, 1, 2]
# [4, 7, 5]
#
# Bước 850 : RIGHT
# [6, 0, 8]
# [3, 1, 2]
# [4, 7, 5]
#
# Bước 851 : RIGHT
# [6, 8, 0]
# [3, 1, 2]
# [4, 7, 5]
#
# Bước 852 : DOWN
# [6, 8, 2]
# [3, 1, 0]
# [4, 7, 5]
#
# Bước 853 : DOWN
# [6, 8, 2]
# [3, 1, 5]
# [4, 7, 0]
#
# Bước 854 : LEFT
# [6, 8, 2]
# [3, 1, 5]
# [4, 0, 7]
#
# Bước 855 : UP
# [6, 8, 2]
# [3, 0, 5]
# [4, 1, 7]
#
# Bước 856 : LEFT
# [6, 8, 2]
# [0, 3, 5]
# [4, 1, 7]
#
# Bước 857 : UP
# [0, 8, 2]
# [6, 3, 5]
# [4, 1, 7]
#
# Bước 858 : RIGHT
# [8, 0, 2]
# [6, 3, 5]
# [4, 1, 7]
#
# Bước 859 : RIGHT
# [8, 2, 0]
# [6, 3, 5]
# [4, 1, 7]
#
# Bước 860 : DOWN
# [8, 2, 5]
# [6, 3, 0]
# [4, 1, 7]
#
# Bước 861 : DOWN
# [8, 2, 5]
# [6, 3, 7]
# [4, 1, 0]
#
# Bước 862 : LEFT
# [8, 2, 5]
# [6, 3, 7]
# [4, 0, 1]
#
# Bước 863 : UP
# [8, 2, 5]
# [6, 0, 7]
# [4, 3, 1]
#
# Bước 864 : LEFT
# [8, 2, 5]
# [0, 6, 7]
# [4, 3, 1]
#
# Bước 865 : DOWN
# [8, 2, 5]
# [4, 6, 7]
# [0, 3, 1]
#
# Bước 866 : RIGHT
# [8, 2, 5]
# [4, 6, 7]
# [3, 0, 1]
#
# Bước 867 : UP
# [8, 2, 5]
# [4, 0, 7]
# [3, 6, 1]
#
# Bước 868 : RIGHT
# [8, 2, 5]
# [4, 7, 0]
# [3, 6, 1]
#
# Bước 869 : UP
# [8, 2, 0]
# [4, 7, 5]
# [3, 6, 1]
#
# Bước 870 : LEFT
# [8, 0, 2]
# [4, 7, 5]
# [3, 6, 1]
#
# Bước 871 : DOWN
# [8, 7, 2]
# [4, 0, 5]
# [3, 6, 1]
#
# Bước 872 : DOWN
# [8, 7, 2]
# [4, 6, 5]
# [3, 0, 1]
#
# Bước 873 : LEFT
# [8, 7, 2]
# [4, 6, 5]
# [0, 3, 1]
#
# Bước 874 : UP
# [8, 7, 2]
# [0, 6, 5]
# [4, 3, 1]
#
# Bước 875 : UP
# [0, 7, 2]
# [8, 6, 5]
# [4, 3, 1]
#
# Bước 876 : RIGHT
# [7, 0, 2]
# [8, 6, 5]
# [4, 3, 1]
#
# Bước 877 : DOWN
# [7, 6, 2]
# [8, 0, 5]
# [4, 3, 1]
#
# Bước 878 : DOWN
# [7, 6, 2]
# [8, 3, 5]
# [4, 0, 1]
#
# Bước 879 : LEFT
# [7, 6, 2]
# [8, 3, 5]
# [0, 4, 1]
#
# Bước 880 : UP
# [7, 6, 2]
# [0, 3, 5]
# [8, 4, 1]
#
# Bước 881 : UP
# [0, 6, 2]
# [7, 3, 5]
# [8, 4, 1]
#
# Bước 882 : RIGHT
# [6, 0, 2]
# [7, 3, 5]
# [8, 4, 1]
#
# Bước 883 : DOWN
# [6, 3, 2]
# [7, 0, 5]
# [8, 4, 1]
#
# Bước 884 : LEFT
# [6, 3, 2]
# [0, 7, 5]
# [8, 4, 1]
#
# Bước 885 : DOWN
# [6, 3, 2]
# [8, 7, 5]
# [0, 4, 1]
#
# Bước 886 : RIGHT
# [6, 3, 2]
# [8, 7, 5]
# [4, 0, 1]
#
# Bước 887 : RIGHT
# [6, 3, 2]
# [8, 7, 5]
# [4, 1, 0]
#
# Bước 888 : UP
# [6, 3, 2]
# [8, 7, 0]
# [4, 1, 5]
#
# Bước 889 : LEFT
# [6, 3, 2]
# [8, 0, 7]
# [4, 1, 5]
#
# Bước 890 : UP
# [6, 0, 2]
# [8, 3, 7]
# [4, 1, 5]
#
# Bước 891 : LEFT
# [0, 6, 2]
# [8, 3, 7]
# [4, 1, 5]
#
# Bước 892 : DOWN
# [8, 6, 2]
# [0, 3, 7]
# [4, 1, 5]
#
# Bước 893 : RIGHT
# [8, 6, 2]
# [3, 0, 7]
# [4, 1, 5]
#
# Bước 894 : UP
# [8, 0, 2]
# [3, 6, 7]
# [4, 1, 5]
#
# Bước 895 : RIGHT
# [8, 2, 0]
# [3, 6, 7]
# [4, 1, 5]
#
# Bước 896 : DOWN
# [8, 2, 7]
# [3, 6, 0]
# [4, 1, 5]
#
# Bước 897 : DOWN
# [8, 2, 7]
# [3, 6, 5]
# [4, 1, 0]
#
# Bước 898 : LEFT
# [8, 2, 7]
# [3, 6, 5]
# [4, 0, 1]
#
# Bước 899 : UP
# [8, 2, 7]
# [3, 0, 5]
# [4, 6, 1]
#
# Bước 900 : UP
# [8, 0, 7]
# [3, 2, 5]
# [4, 6, 1]
#
# Bước 901 : LEFT
# [0, 8, 7]
# [3, 2, 5]
# [4, 6, 1]
#
# Bước 902 : DOWN
# [3, 8, 7]
# [0, 2, 5]
# [4, 6, 1]
#
# Bước 903 : DOWN
# [3, 8, 7]
# [4, 2, 5]
# [0, 6, 1]
#
# Bước 904 : RIGHT
# [3, 8, 7]
# [4, 2, 5]
# [6, 0, 1]
#
# Bước 905 : UP
# [3, 8, 7]
# [4, 0, 5]
# [6, 2, 1]
#
# Bước 906 : RIGHT
# [3, 8, 7]
# [4, 5, 0]
# [6, 2, 1]
#
# Bước 907 : UP
# [3, 8, 0]
# [4, 5, 7]
# [6, 2, 1]
#
# Bước 908 : LEFT
# [3, 0, 8]
# [4, 5, 7]
# [6, 2, 1]
#
# Bước 909 : LEFT
# [0, 3, 8]
# [4, 5, 7]
# [6, 2, 1]
#
# Bước 910 : DOWN
# [4, 3, 8]
# [0, 5, 7]
# [6, 2, 1]
#
# Bước 911 : DOWN
# [4, 3, 8]
# [6, 5, 7]
# [0, 2, 1]
#
# Bước 912 : RIGHT
# [4, 3, 8]
# [6, 5, 7]
# [2, 0, 1]
#
# Bước 913 : UP
# [4, 3, 8]
# [6, 0, 7]
# [2, 5, 1]
#
# Bước 914 : RIGHT
# [4, 3, 8]
# [6, 7, 0]
# [2, 5, 1]
#
# Bước 915 : DOWN
# [4, 3, 8]
# [6, 7, 1]
# [2, 5, 0]
#
# Bước 916 : LEFT
# [4, 3, 8]
# [6, 7, 1]
# [2, 0, 5]
#
# Bước 917 : LEFT
# [4, 3, 8]
# [6, 7, 1]
# [0, 2, 5]
#
# Bước 918 : UP
# [4, 3, 8]
# [0, 7, 1]
# [6, 2, 5]
#
# Bước 919 : UP
# [0, 3, 8]
# [4, 7, 1]
# [6, 2, 5]
#
# Bước 920 : RIGHT
# [3, 0, 8]
# [4, 7, 1]
# [6, 2, 5]
#
# Bước 921 : DOWN
# [3, 7, 8]
# [4, 0, 1]
# [6, 2, 5]
#
# Bước 922 : DOWN
# [3, 7, 8]
# [4, 2, 1]
# [6, 0, 5]
#
# Bước 923 : RIGHT
# [3, 7, 8]
# [4, 2, 1]
# [6, 5, 0]
#
# Bước 924 : UP
# [3, 7, 8]
# [4, 2, 0]
# [6, 5, 1]
#
# Bước 925 : UP
# [3, 7, 0]
# [4, 2, 8]
# [6, 5, 1]
#
# Bước 926 : LEFT
# [3, 0, 7]
# [4, 2, 8]
# [6, 5, 1]
#
# Bước 927 : LEFT
# [0, 3, 7]
# [4, 2, 8]
# [6, 5, 1]
#
# Bước 928 : DOWN
# [4, 3, 7]
# [0, 2, 8]
# [6, 5, 1]
#
# Bước 929 : DOWN
# [4, 3, 7]
# [6, 2, 8]
# [0, 5, 1]
#
# Bước 930 : RIGHT
# [4, 3, 7]
# [6, 2, 8]
# [5, 0, 1]
#
# Bước 931 : RIGHT
# [4, 3, 7]
# [6, 2, 8]
# [5, 1, 0]
#
# Bước 932 : UP
# [4, 3, 7]
# [6, 2, 0]
# [5, 1, 8]
#
# Bước 933 : UP
# [4, 3, 0]
# [6, 2, 7]
# [5, 1, 8]
#
# Bước 934 : LEFT
# [4, 0, 3]
# [6, 2, 7]
# [5, 1, 8]
#
# Bước 935 : DOWN
# [4, 2, 3]
# [6, 0, 7]
# [5, 1, 8]
#
# Bước 936 : LEFT
# [4, 2, 3]
# [0, 6, 7]
# [5, 1, 8]
#
# Bước 937 : DOWN
# [4, 2, 3]
# [5, 6, 7]
# [0, 1, 8]
#
# Bước 938 : RIGHT
# [4, 2, 3]
# [5, 6, 7]
# [1, 0, 8]
#
# Bước 939 : RIGHT
# [4, 2, 3]
# [5, 6, 7]
# [1, 8, 0]
#
# Bước 940 : UP
# [4, 2, 3]
# [5, 6, 0]
# [1, 8, 7]
#
# Bước 941 : LEFT
# [4, 2, 3]
# [5, 0, 6]
# [1, 8, 7]
#
# Bước 942 : UP
# [4, 0, 3]
# [5, 2, 6]
# [1, 8, 7]
#
# Bước 943 : RIGHT
# [4, 3, 0]
# [5, 2, 6]
# [1, 8, 7]
#
# Bước 944 : DOWN
# [4, 3, 6]
# [5, 2, 0]
# [1, 8, 7]
#
# Bước 945 : LEFT
# [4, 3, 6]
# [5, 0, 2]
# [1, 8, 7]
#
# Bước 946 : UP
# [4, 0, 6]
# [5, 3, 2]
# [1, 8, 7]
#
# Bước 947 : RIGHT
# [4, 6, 0]
# [5, 3, 2]
# [1, 8, 7]
#
# Bước 948 : DOWN
# [4, 6, 2]
# [5, 3, 0]
# [1, 8, 7]
#
# Bước 949 : LEFT
# [4, 6, 2]
# [5, 0, 3]
# [1, 8, 7]
#
# Bước 950 : UP
# [4, 0, 2]
# [5, 6, 3]
# [1, 8, 7]
#
# Bước 951 : LEFT
# [0, 4, 2]
# [5, 6, 3]
# [1, 8, 7]
#
# Bước 952 : DOWN
# [5, 4, 2]
# [0, 6, 3]
# [1, 8, 7]
#
# Bước 953 : DOWN
# [5, 4, 2]
# [1, 6, 3]
# [0, 8, 7]
#
# Bước 954 : RIGHT
# [5, 4, 2]
# [1, 6, 3]
# [8, 0, 7]
#
# Bước 955 : RIGHT
# [5, 4, 2]
# [1, 6, 3]
# [8, 7, 0]
#
# Bước 956 : UP
# [5, 4, 2]
# [1, 6, 0]
# [8, 7, 3]
#
# Bước 957 : LEFT
# [5, 4, 2]
# [1, 0, 6]
# [8, 7, 3]
#
# Bước 958 : LEFT
# [5, 4, 2]
# [0, 1, 6]
# [8, 7, 3]
#
# Bước 959 : DOWN
# [5, 4, 2]
# [8, 1, 6]
# [0, 7, 3]
#
# Bước 960 : RIGHT
# [5, 4, 2]
# [8, 1, 6]
# [7, 0, 3]
#
# Bước 961 : RIGHT
# [5, 4, 2]
# [8, 1, 6]
# [7, 3, 0]
#
# Bước 962 : UP
# [5, 4, 2]
# [8, 1, 0]
# [7, 3, 6]
#
# Bước 963 : LEFT
# [5, 4, 2]
# [8, 0, 1]
# [7, 3, 6]
#
# Bước 964 : UP
# [5, 0, 2]
# [8, 4, 1]
# [7, 3, 6]
#
# Bước 965 : RIGHT
# [5, 2, 0]
# [8, 4, 1]
# [7, 3, 6]
#
# Bước 966 : DOWN
# [5, 2, 1]
# [8, 4, 0]
# [7, 3, 6]
#
# Bước 967 : DOWN
# [5, 2, 1]
# [8, 4, 6]
# [7, 3, 0]
#
# Bước 968 : LEFT
# [5, 2, 1]
# [8, 4, 6]
# [7, 0, 3]
#
# Bước 969 : UP
# [5, 2, 1]
# [8, 0, 6]
# [7, 4, 3]
#
# Bước 970 : LEFT
# [5, 2, 1]
# [0, 8, 6]
# [7, 4, 3]
#
# Bước 971 : DOWN
# [5, 2, 1]
# [7, 8, 6]
# [0, 4, 3]
#
# Bước 972 : RIGHT
# [5, 2, 1]
# [7, 8, 6]
# [4, 0, 3]
#
# Bước 973 : UP
# [5, 2, 1]
# [7, 0, 6]
# [4, 8, 3]
#
# Bước 974 : RIGHT
# [5, 2, 1]
# [7, 6, 0]
# [4, 8, 3]
#
# Bước 975 : UP
# [5, 2, 0]
# [7, 6, 1]
# [4, 8, 3]
#
# Bước 976 : LEFT
# [5, 0, 2]
# [7, 6, 1]
# [4, 8, 3]
#
# Bước 977 : DOWN
# [5, 6, 2]
# [7, 0, 1]
# [4, 8, 3]
#
# Bước 978 : LEFT
# [5, 6, 2]
# [0, 7, 1]
# [4, 8, 3]
#
# Bước 979 : UP
# [0, 6, 2]
# [5, 7, 1]
# [4, 8, 3]
#
# Bước 980 : RIGHT
# [6, 0, 2]
# [5, 7, 1]
# [4, 8, 3]
#
# Bước 981 : DOWN
# [6, 7, 2]
# [5, 0, 1]
# [4, 8, 3]
#
# Bước 982 : DOWN
# [6, 7, 2]
# [5, 8, 1]
# [4, 0, 3]
#
# Bước 983 : LEFT
# [6, 7, 2]
# [5, 8, 1]
# [0, 4, 3]
#
# Bước 984 : UP
# [6, 7, 2]
# [0, 8, 1]
# [5, 4, 3]
#
# Bước 985 : UP
# [0, 7, 2]
# [6, 8, 1]
# [5, 4, 3]
#
# Bước 986 : RIGHT
# [7, 0, 2]
# [6, 8, 1]
# [5, 4, 3]
#
# Bước 987 : DOWN
# [7, 8, 2]
# [6, 0, 1]
# [5, 4, 3]
#
# Bước 988 : LEFT
# [7, 8, 2]
# [0, 6, 1]
# [5, 4, 3]
#
# Bước 989 : DOWN
# [7, 8, 2]
# [5, 6, 1]
# [0, 4, 3]
#
# Bước 990 : RIGHT
# [7, 8, 2]
# [5, 6, 1]
# [4, 0, 3]
#
# Bước 991 : RIGHT
# [7, 8, 2]
# [5, 6, 1]
# [4, 3, 0]
#
# Bước 992 : UP
# [7, 8, 2]
# [5, 6, 0]
# [4, 3, 1]
#
# Bước 993 : UP
# [7, 8, 0]
# [5, 6, 2]
# [4, 3, 1]
#
# Bước 994 : LEFT
# [7, 0, 8]
# [5, 6, 2]
# [4, 3, 1]
#
# Bước 995 : DOWN
# [7, 6, 8]
# [5, 0, 2]
# [4, 3, 1]
#
# Bước 996 : LEFT
# [7, 6, 8]
# [0, 5, 2]
# [4, 3, 1]
#
# Bước 997 : DOWN
# [7, 6, 8]
# [4, 5, 2]
# [0, 3, 1]
#
# Bước 998 : RIGHT
# [7, 6, 8]
# [4, 5, 2]
# [3, 0, 1]
#
# Bước 999 : UP
# [7, 6, 8]
# [4, 0, 2]
# [3, 5, 1]
#
# Bước 1000 : RIGHT
# [7, 6, 8]
# [4, 2, 0]
# [3, 5, 1]
#
# Dừng lại sau 1000 bước
